# %%
import re
import qiskit
import json
import time
import os
import numpy as np
from qiskit import transpile, QuantumCircuit
import time

from fast_generator import fc_tree_commute_lookahead_fast
from benchmarks.UCCSD_entanglers import generate_UCCSD_entanglers
from circuit_generator import construct_qcc_circuit

import numpy as np
from rustiq import pauli_network_synthesis, Metric
from rustiq.utils import entangling_count, entangling_depth
# from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
import rustiq

from qiskit.transpiler import CouplingMap

print(qiskit.__version__)
# Out:
# 1.1.1

# %%
def convert_to_circuit(circuit: list) -> QuantumCircuit:
    """
    Converts a circuit into a CNOT + H + S + RZ(theta) to a quantumcircuit
    """
    num_qubits=len(set([num for op in circuit for num in op[1]]))
    new_circuit=QuantumCircuit(num_qubits)
    for gate in circuit:
        op=gate[0]
        params=gate[1]
        assert op in ["CNOT", "CZ", "H", "S", "Sd", "X", "Z", "SqrtX", "SqrtXd"], f"op not allowed {op}"
        if op=="CNOT":
            new_circuit.cx(params[0], params[1])
        elif op=="CZ":
            new_circuit.cz(params[0], params[1])
        elif op=="H":
            new_circuit.h(params[0])
        elif op=="S":
            new_circuit.s(params[0])
        elif op=="Sd":
            new_circuit.sdg(params[0])
        elif op=="X":
            new_circuit.x(params[0])
        elif op=="Z":
            new_circuit.z(params[0])
        elif op=="SqrtX":
            new_circuit.sx(params[0])
        elif op=="SqrtXd":
            new_circuit.sxdg(params[0])
    return new_circuit

# %%
#Compare json files in a specific folder
def run_experiment_folder(folder_path = None, filename = None, save_output = False, lookahead_size = 5):

    if filename == None:
        file_list = os.listdir(folder_path)
    else:
        file_list = [filename]
    # Iterate over all files in the folder
    for filename in file_list:
        # Check if the file is a JSON file
        if filename.endswith(".json"):
            results = []
            # Print the filename
            print(filename)
            with open(folder_path + '/' + filename, "r") as file:
                paulis = json.load(file)

            # Function to check if a string contains only 'I' characters
            def is_all_identity(pauli):
                return all(char == 'I' for char in pauli)

            # Filter the list to remove all identity Paulis
            test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
            test_params = [0.01 * i for i in range(len(test_paulis))]

            # Measure time for our method
            start_time = time.time()
            opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
            opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            our_time = end_time - start_time

            start_time = time.time()
            opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
            opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            combined_time = end_time - start_time
            
            # Measure time for Qiskit method
            start_time = time.time()
            origin_qc = construct_qcc_circuit(entanglers=test_paulis, params=test_params, barrier=False)
            origin_qiskit = transpile(origin_qc, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            qiskit_time = end_time - start_time

            # Measure time for RustiQ method
            start_time = time.time()
            circuit = pauli_network_synthesis(test_paulis, Metric.COUNT, True, fix_clifford=True)
            qiskit_circ_rustiq=convert_to_circuit(circuit)
            # print(qiskit_circ_rustiq)
            # can't optimize with level 3 since rustiq returns an optimized circuit missing some single qubit gates.
            qiskit_circ_rustiq = transpile(qiskit_circ_rustiq, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            rustiq_time = end_time - start_time
        
            # Collect results
            result = {
                "num_paulis": len(test_paulis),
                "times": {
                    "our_time": our_time,
                    "combined_time": combined_time,
                    "qiskit_time": qiskit_time,
                    "rustiq_time": rustiq_time
                },
                "gate_counts": {
                    "our_method": opt_qc_f.count_ops().get('cx', 0),
                    "combined_method": opt_qiskit.count_ops().get('cx', 0),
                    "qiskit_method": origin_qiskit.count_ops().get('cx', 0),
                    "rustiq_method": qiskit_circ_rustiq.count_ops().get('cx', 0)
                },
                "circuit_entangling_depth": {
                    "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
                    "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1),
                    "qiskit_method": origin_qiskit.depth(lambda instr: len(instr.qubits) > 1),
                    "rustiq_method": qiskit_circ_rustiq.depth(lambda instr: len(instr.qubits) > 1)
                },
                "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_grid/test_' + filename
            }
            print(result)
            results.append(result)
            if save_output == True:
                # Save test_paulis to a separate JSON file
                with open(f'benchmarks/results_hardware_topology_ibm_grid/test_' + filename, 'w') as paulis_file:
                    json.dump([test_paulis, results], paulis_file, indent=4)

# %%
#Compare a given list of paulis
def run_experiment_paulis(test_paulis, test_params = None, save_output = False, lookahead_size = 5, filename = "Paulis"):

    results = []

    def is_all_identity(pauli):
        return all(char == 'I' for char in pauli)
    paulis = test_paulis
    # Filter the list to remove all identity Paulis
    test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
    if test_params is None:
        test_params = [0.01 * i for i in range(len(test_paulis))]

    # Measure time for our method
    start_time = time.time()
    opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
    opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    our_time = end_time - start_time

    start_time = time.time()
    opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
    opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    combined_time = end_time - start_time
    
    # Measure time for Qiskit method
    start_time = time.time()
    origin_qc = construct_qcc_circuit(entanglers=test_paulis, params=test_params, barrier=False)
    origin_qiskit = transpile(origin_qc, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    qiskit_time = end_time - start_time

    # Measure time for RustiQ method
    start_time = time.time()
    circuit = pauli_network_synthesis(test_paulis, Metric.COUNT, True, fix_clifford=True)
    qiskit_circ_rustiq=convert_to_circuit(circuit)
    # print(qiskit_circ_rustiq)
    # can't optimize with level 3 since rustiq returns an optimized circuit missing some single qubit gates.
    qiskit_circ_rustiq = transpile(qiskit_circ_rustiq, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    rustiq_time = end_time - start_time
    
    # Collect results
    result = {
        "num_paulis": len(test_paulis),
        "times": {
            "our_time": our_time,
            "combined_time": combined_time,
            "qiskit_time": qiskit_time,
            "rustiq_time": rustiq_time
        },
        "gate_counts": {
            "our_method": opt_qc_f.count_ops().get('cx', 0),
            "combined_method": opt_qiskit.count_ops().get('cx', 0),
            "qiskit_method": origin_qiskit.count_ops().get('cx', 0),
            "rustiq_method": qiskit_circ_rustiq.count_ops().get('cx', 0)
        },
        "circuit_entangling_depth": {
            "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
            "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1),
            "qiskit_method": origin_qiskit.depth(lambda instr: len(instr.qubits) > 1),
            "rustiq_method": qiskit_circ_rustiq.depth(lambda instr: len(instr.qubits) > 1)
        },
        "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_grid/test_' + filename
    }
    print(result)
    results.append(result)
    if save_output == True:
        # Save test_paulis to a separate JSON file
        with open(f'benchmarks/results_hardware_topology_ibm_grid/test_' + filename, 'w') as paulis_file:
            json.dump([test_paulis, results], paulis_file, indent=4)
    return sorted_entanglers_f

# %%
#first compare the UCCSD ansatz
electrons_list = [2, 2, 4, 6, 8, 10,] #12]
orbitals_list = [4, 6, 8, 12, 16, 20,] #24]
#First evaluate the UCCSD ansatz:
for i, (x, y) in enumerate(zip(electrons_list, orbitals_list)):
    test_paulis = generate_UCCSD_entanglers(x, y)
    entanglers = run_experiment_paulis(test_paulis = test_paulis, save_output = True, lookahead_size = 5, filename=f"Paulis{len(test_paulis)}.json")
# Out:
# {'num_paulis': 24, 'times': {'our_time': 0.519160270690918, 'combined_time': 0.2732691764831543, 'qiskit_time': 0.27725958824157715, 'rustiq_time': 0.160081148147583}, 'gate_counts': {'our_method': 66, 'combined_method': 41, 'qiskit_method': 41, 'rustiq_method': 84}, 'circuit_entangling_depth': {'our_method': 56, 'combined_method': 34, 'qiskit_method': 41, 'rustiq_method': 72}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis24.json'}
# {'num_paulis': 80, 'times': {'our_time': 1.5495874881744385, 'combined_time': 0.8403606414794922, 'qiskit_time': 0.6208512783050537, 'rustiq_time': 0.7512326240539551}, 'gate_counts': {'our_method': 436, 'combined_method': 165, 'qiskit_method': 183, 'rustiq_method': 632}, 'circuit_entangling_depth': {'our_method': 317, 'combined_method': 136, 'qiskit_method': 180, 'rustiq_method': 434}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis80.json'}
# {'num_paulis': 320, 'times': {'our_time': 6.152129173278809, 'combined_time': 3.8526201248168945, 'qiskit_time': 2.3210792541503906, 'rustiq_time': 2.9977610111236572}, 'gate_counts': {'our_method': 2469, 'combined_method': 995, 'qiskit_method': 1068, 'rustiq_method': 4059}, 'circuit_entangling_depth': {'our_method': 1537, 'combined_method': 760, 'qiskit_method': 1020, 'rustiq_method': 2538}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis320.json'}
# {'num_paulis': 1656, 'times': {'our_time': 32.74223756790161, 'combined_time': 25.895074129104614, 'qiskit_time': 19.26159644126892, 'rustiq_time': 26.63047957420349}, 'gate_counts': {'our_method': 12555, 'combined_method': 6697, 'qiskit_method': 6396, 'rustiq_method': 21154}, 'circuit_entangling_depth': {'our_method': 7106, 'combined_method': 4344, 'qiskit_method': 5875, 'rustiq_method': 12345}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis1656.json'}
# {'num_paulis': 5376, 'times': {'our_time': 119.12271499633789, 'combined_time': 97.72168016433716, 'qiskit_time': 84.32945704460144, 'rustiq_time': 749.3963630199432}, 'gate_counts': {'our_method': 57464, 'combined_method': 27885, 'qiskit_method': 27789, 'rustiq_method': 102614}, 'circuit_entangling_depth': {'our_method': 29352, 'combined_method': 16864, 'qiskit_method': 25360, 'rustiq_method': 52032}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis5376.json'}
# {'num_paulis': 13400, 'times': {'our_time': 344.7894380092621, 'combined_time': 292.33608055114746, 'qiskit_time': 300.91425108909607, 'rustiq_time': 15257.82778596878}, 'gate_counts': {'our_method': 192288, 'combined_method': 89257, 'qiskit_method': 86486, 'rustiq_method': 296602}, 'circuit_entangling_depth': {'our_method': 89740, 'combined_method': 49578, 'qiskit_method': 79425, 'rustiq_method': 141573}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_Paulis13400.json'}

# %%
#Then compare the Hamiltonian simulation paulis in HS_paulis folder
run_experiment_folder(folder_path = "benchmarks/HS_paulis", save_output = True, lookahead_size = 10)
# Out:
# benzene.json
# {'num_paulis': 1254, 'times': {'our_time': 32.605815410614014, 'combined_time': 28.063989400863647, 'qiskit_time': 9.4660165309906, 'rustiq_time': 22.092109441757202}, 'gate_counts': {'our_method': 18712, 'combined_method': 9933, 'qiskit_method': 9123, 'rustiq_method': 17211}, 'circuit_entangling_depth': {'our_method': 9367, 'combined_method': 6287, 'qiskit_method': 8041, 'rustiq_method': 9106}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_benzene.json'}
# H2O.json
# {'num_paulis': 184, 'times': {'our_time': 3.547217607498169, 'combined_time': 2.7195138931274414, 'qiskit_time': 1.3320658206939697, 'rustiq_time': 1.767524003982544}, 'gate_counts': {'our_method': 1716, 'combined_method': 650, 'qiskit_method': 988, 'rustiq_method': 1848}, 'circuit_entangling_depth': {'our_method': 996, 'combined_method': 473, 'qiskit_method': 894, 'rustiq_method': 1109}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_H2O.json'}
# LiH.json
# {'num_paulis': 61, 'times': {'our_time': 1.0346565246582031, 'combined_time': 0.8810670375823975, 'qiskit_time': 0.38901782035827637, 'rustiq_time': 0.5612189769744873}, 'gate_counts': {'our_method': 285, 'combined_method': 123, 'qiskit_method': 222, 'rustiq_method': 456}, 'circuit_entangling_depth': {'our_method': 196, 'combined_method': 101, 'qiskit_method': 201, 'rustiq_method': 298}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_LiH.json'}

# %%
#Then compare the MAXCUT paulis in max_cut_paulis folder

run_experiment_folder(folder_path = "benchmarks/max_cut_paulis", save_output = True, lookahead_size = 10)
# Out:
# max_cut_benchmark_connected_n10_e12_l1.json
# {'num_paulis': 22, 'times': {'our_time': 0.4507935047149658, 'combined_time': 0.43914008140563965, 'qiskit_time': 0.05584979057312012, 'rustiq_time': 0.09578919410705566}, 'gate_counts': {'our_method': 237, 'combined_method': 60, 'qiskit_method': 28, 'rustiq_method': 231}, 'circuit_entangling_depth': {'our_method': 117, 'combined_method': 46, 'qiskit_method': 18, 'rustiq_method': 102}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n10_e12_l1.json'}
# max_cut_benchmark_connected_n10_e12_l3.json
# {'num_paulis': 66, 'times': {'our_time': 1.4040133953094482, 'combined_time': 1.5492284297943115, 'qiskit_time': 0.14502763748168945, 'rustiq_time': 0.21342968940734863}, 'gate_counts': {'our_method': 683, 'combined_method': 199, 'qiskit_method': 83, 'rustiq_method': 515}, 'circuit_entangling_depth': {'our_method': 336, 'combined_method': 130, 'qiskit_method': 42, 'rustiq_method': 243}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n10_e12_l3.json'}
# max_cut_benchmark_connected_n15_e63_l1.json
# {'num_paulis': 78, 'times': {'our_time': 4.920711278915405, 'combined_time': 4.350765705108643, 'qiskit_time': 0.14869165420532227, 'rustiq_time': 0.28790831565856934}, 'gate_counts': {'our_method': 667, 'combined_method': 213, 'qiskit_method': 211, 'rustiq_method': 780}, 'circuit_entangling_depth': {'our_method': 275, 'combined_method': 137, 'qiskit_method': 89, 'rustiq_method': 312}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n15_e63_l1.json'}
# max_cut_benchmark_connected_n15_e63_l3.json
# {'num_paulis': 234, 'times': {'our_time': 14.130317211151123, 'combined_time': 12.487841606140137, 'qiskit_time': 0.5256619453430176, 'rustiq_time': 0.8245913982391357}, 'gate_counts': {'our_method': 1631, 'combined_method': 692, 'qiskit_method': 710, 'rustiq_method': 1836}, 'circuit_entangling_depth': {'our_method': 689, 'combined_method': 378, 'qiskit_method': 299, 'rustiq_method': 746}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n15_e63_l3.json'}
# max_cut_benchmark_connected_n20_e117_l1.json
# {'num_paulis': 137, 'times': {'our_time': 15.05680775642395, 'combined_time': 14.828911542892456, 'qiskit_time': 0.2534923553466797, 'rustiq_time': 0.5579566955566406}, 'gate_counts': {'our_method': 1442, 'combined_method': 498, 'qiskit_method': 469, 'rustiq_method': 1442}, 'circuit_entangling_depth': {'our_method': 523, 'combined_method': 238, 'qiskit_method': 187, 'rustiq_method': 495}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n20_e117_l1.json'}
# max_cut_benchmark_connected_n20_e117_l3.json
# {'num_paulis': 411, 'times': {'our_time': 48.21121263504028, 'combined_time': 46.44152593612671, 'qiskit_time': 0.9944384098052979, 'rustiq_time': 1.5334434509277344}, 'gate_counts': {'our_method': 4016, 'combined_method': 1658, 'qiskit_method': 1592, 'rustiq_method': 4351}, 'circuit_entangling_depth': {'our_method': 1483, 'combined_method': 821, 'qiskit_method': 651, 'rustiq_method': 1755}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_connected_n20_e117_l3.json'}
# max_cut_benchmark_regular_n10_e3_l1.json
# {'num_paulis': 25, 'times': {'our_time': 0.5840024948120117, 'combined_time': 0.44119787216186523, 'qiskit_time': 0.04933929443359375, 'rustiq_time': 0.10732007026672363}, 'gate_counts': {'our_method': 258, 'combined_method': 65, 'qiskit_method': 37, 'rustiq_method': 294}, 'circuit_entangling_depth': {'our_method': 108, 'combined_method': 42, 'qiskit_method': 19, 'rustiq_method': 139}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n10_e3_l1.json'}
# max_cut_benchmark_regular_n10_e3_l3.json
# {'num_paulis': 75, 'times': {'our_time': 1.5000848770141602, 'combined_time': 1.535487174987793, 'qiskit_time': 0.12966132164001465, 'rustiq_time': 0.22744345664978027}, 'gate_counts': {'our_method': 600, 'combined_method': 171, 'qiskit_method': 114, 'rustiq_method': 838}, 'circuit_entangling_depth': {'our_method': 277, 'combined_method': 107, 'qiskit_method': 48, 'rustiq_method': 356}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n10_e3_l3.json'}
# max_cut_benchmark_regular_n15_e4_l1.json
# {'num_paulis': 45, 'times': {'our_time': 1.492847204208374, 'combined_time': 1.6402690410614014, 'qiskit_time': 0.08672070503234863, 'rustiq_time': 0.25147175788879395}, 'gate_counts': {'our_method': 579, 'combined_method': 153, 'qiskit_method': 98, 'rustiq_method': 544}, 'circuit_entangling_depth': {'our_method': 217, 'combined_method': 90, 'qiskit_method': 51, 'rustiq_method': 219}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n15_e4_l1.json'}
# max_cut_benchmark_regular_n15_e4_l3.json
# {'num_paulis': 135, 'times': {'our_time': 4.931878089904785, 'combined_time': 4.76926326751709, 'qiskit_time': 0.38028621673583984, 'rustiq_time': 0.5565059185028076}, 'gate_counts': {'our_method': 1637, 'combined_method': 549, 'qiskit_method': 349, 'rustiq_method': 1701}, 'circuit_entangling_depth': {'our_method': 640, 'combined_method': 319, 'qiskit_method': 176, 'rustiq_method': 720}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n15_e4_l3.json'}
# max_cut_benchmark_regular_n20_e12_l1.json
# {'num_paulis': 140, 'times': {'our_time': 17.14757466316223, 'combined_time': 16.62033200263977, 'qiskit_time': 0.42177391052246094, 'rustiq_time': 0.5150110721588135}, 'gate_counts': {'our_method': 1558, 'combined_method': 524, 'qiskit_method': 525, 'rustiq_method': 1688}, 'circuit_entangling_depth': {'our_method': 605, 'combined_method': 266, 'qiskit_method': 329, 'rustiq_method': 625}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e12_l1.json'}
# max_cut_benchmark_regular_n20_e12_l3.json
# {'num_paulis': 420, 'times': {'our_time': 52.41993951797485, 'combined_time': 50.374709606170654, 'qiskit_time': 0.8744344711303711, 'rustiq_time': 1.384606122970581}, 'gate_counts': {'our_method': 3936, 'combined_method': 1667, 'qiskit_method': 1686, 'rustiq_method': 4499}, 'circuit_entangling_depth': {'our_method': 1630, 'combined_method': 831, 'qiskit_method': 964, 'rustiq_method': 1615}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e12_l3.json'}
# max_cut_benchmark_regular_n20_e3_l1.json
# {'num_paulis': 50, 'times': {'our_time': 1.9531373977661133, 'combined_time': 2.202690362930298, 'qiskit_time': 0.13251852989196777, 'rustiq_time': 0.2517969608306885}, 'gate_counts': {'our_method': 472, 'combined_method': 158, 'qiskit_method': 84, 'rustiq_method': 678}, 'circuit_entangling_depth': {'our_method': 177, 'combined_method': 65, 'qiskit_method': 26, 'rustiq_method': 259}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e3_l1.json'}
# max_cut_benchmark_regular_n20_e3_l3.json
# {'num_paulis': 150, 'times': {'our_time': 6.807092189788818, 'combined_time': 6.869022369384766, 'qiskit_time': 0.2541823387145996, 'rustiq_time': 0.8187789916992188}, 'gate_counts': {'our_method': 1547, 'combined_method': 637, 'qiskit_method': 259, 'rustiq_method': 1876}, 'circuit_entangling_depth': {'our_method': 531, 'combined_method': 319, 'qiskit_method': 66, 'rustiq_method': 679}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e3_l3.json'}
# max_cut_benchmark_regular_n20_e4_l1.json
# {'num_paulis': 60, 'times': {'our_time': 2.9974114894866943, 'combined_time': 2.8739399909973145, 'qiskit_time': 0.10836195945739746, 'rustiq_time': 0.303295373916626}, 'gate_counts': {'our_method': 837, 'combined_method': 230, 'qiskit_method': 143, 'rustiq_method': 858}, 'circuit_entangling_depth': {'our_method': 280, 'combined_method': 100, 'qiskit_method': 60, 'rustiq_method': 312}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e4_l1.json'}
# max_cut_benchmark_regular_n20_e4_l3.json
# {'num_paulis': 180, 'times': {'our_time': 9.643685817718506, 'combined_time': 8.98224425315857, 'qiskit_time': 0.2749369144439697, 'rustiq_time': 0.919792890548706}, 'gate_counts': {'our_method': 2376, 'combined_method': 946, 'qiskit_method': 509, 'rustiq_method': 2965}, 'circuit_entangling_depth': {'our_method': 860, 'combined_method': 472, 'qiskit_method': 179, 'rustiq_method': 1090}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e4_l3.json'}
# max_cut_benchmark_regular_n20_e8_l1.json
# {'num_paulis': 100, 'times': {'our_time': 8.294843673706055, 'combined_time': 8.18482232093811, 'qiskit_time': 0.17476272583007812, 'rustiq_time': 0.45245838165283203}, 'gate_counts': {'our_method': 1274, 'combined_method': 485, 'qiskit_method': 329, 'rustiq_method': 1415}, 'circuit_entangling_depth': {'our_method': 501, 'combined_method': 252, 'qiskit_method': 184, 'rustiq_method': 536}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e8_l1.json'}
# max_cut_benchmark_regular_n20_e8_l3.json
# {'num_paulis': 300, 'times': {'our_time': 27.76430320739746, 'combined_time': 25.08763551712036, 'qiskit_time': 0.6242420673370361, 'rustiq_time': 1.2297511100769043}, 'gate_counts': {'our_method': 4465, 'combined_method': 1957, 'qiskit_method': 1147, 'rustiq_method': 3643}, 'circuit_entangling_depth': {'our_method': 1810, 'combined_method': 1012, 'qiskit_method': 608, 'rustiq_method': 1242}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_max_cut_benchmark_regular_n20_e8_l3.json'}

# %%
#Labs

run_experiment_folder(folder_path = "benchmarks/labs_paulis", save_output = True, lookahead_size = 10)
# Out:
# labs_n10_layers1.json
# {'num_paulis': 80, 'times': {'our_time': 4.3212361335754395, 'combined_time': 3.7086567878723145, 'qiskit_time': 0.19167232513427734, 'rustiq_time': 0.3820643424987793}, 'gate_counts': {'our_method': 770, 'combined_method': 257, 'qiskit_method': 542, 'rustiq_method': 815}, 'circuit_entangling_depth': {'our_method': 396, 'combined_method': 174, 'qiskit_method': 346, 'rustiq_method': 406}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n10_layers1.json'}
# labs_n10_layers3.json
# {'num_paulis': 240, 'times': {'our_time': 12.695252895355225, 'combined_time': 11.308904647827148, 'qiskit_time': 0.9813215732574463, 'rustiq_time': 0.8672194480895996}, 'gate_counts': {'our_method': 2267, 'combined_method': 792, 'qiskit_method': 1670, 'rustiq_method': 2278}, 'circuit_entangling_depth': {'our_method': 1191, 'combined_method': 592, 'qiskit_method': 1131, 'rustiq_method': 1167}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n10_layers3.json'}
# labs_n11_layers1.json
# {'num_paulis': 106, 'times': {'our_time': 7.298143625259399, 'combined_time': 6.385199546813965, 'qiskit_time': 0.2615187168121338, 'rustiq_time': 0.5340497493743896}, 'gate_counts': {'our_method': 1184, 'combined_method': 340, 'qiskit_method': 762, 'rustiq_method': 1362}, 'circuit_entangling_depth': {'our_method': 594, 'combined_method': 239, 'qiskit_method': 459, 'rustiq_method': 668}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n11_layers1.json'}
# labs_n11_layers3.json
# {'num_paulis': 318, 'times': {'our_time': 20.931175231933594, 'combined_time': 19.93096089363098, 'qiskit_time': 0.9021916389465332, 'rustiq_time': 1.1655628681182861}, 'gate_counts': {'our_method': 3532, 'combined_method': 1143, 'qiskit_method': 2404, 'rustiq_method': 3714}, 'circuit_entangling_depth': {'our_method': 1742, 'combined_method': 775, 'qiskit_method': 1512, 'rustiq_method': 1770}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n11_layers3.json'}
# labs_n12_layers1.json
# {'num_paulis': 137, 'times': {'our_time': 12.52483606338501, 'combined_time': 12.411407470703125, 'qiskit_time': 0.49525022506713867, 'rustiq_time': 0.46288394927978516}, 'gate_counts': {'our_method': 1182, 'combined_method': 474, 'qiskit_method': 1036, 'rustiq_method': 1208}, 'circuit_entangling_depth': {'our_method': 515, 'combined_method': 314, 'qiskit_method': 653, 'rustiq_method': 556}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n12_layers1.json'}
# labs_n12_layers3.json
# {'num_paulis': 411, 'times': {'our_time': 36.56150484085083, 'combined_time': 36.3233528137207, 'qiskit_time': 1.3903040885925293, 'rustiq_time': 1.501551866531372}, 'gate_counts': {'our_method': 3238, 'combined_method': 1647, 'qiskit_method': 3175, 'rustiq_method': 3108}, 'circuit_entangling_depth': {'our_method': 1684, 'combined_method': 1039, 'qiskit_method': 1990, 'rustiq_method': 1494}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n12_layers3.json'}
# labs_n13_layers1.json
# {'num_paulis': 174, 'times': {'our_time': 20.320988655090332, 'combined_time': 19.051769971847534, 'qiskit_time': 0.5838005542755127, 'rustiq_time': 0.6988794803619385}, 'gate_counts': {'our_method': 1458, 'combined_method': 651, 'qiskit_method': 1372, 'rustiq_method': 1470}, 'circuit_entangling_depth': {'our_method': 695, 'combined_method': 422, 'qiskit_method': 839, 'rustiq_method': 736}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n13_layers1.json'}
# labs_n13_layers3.json
# {'num_paulis': 522, 'times': {'our_time': 60.606748819351196, 'combined_time': 57.638930320739746, 'qiskit_time': 1.506899118423462, 'rustiq_time': 2.2779574394226074}, 'gate_counts': {'our_method': 4412, 'combined_method': 2236, 'qiskit_method': 4241, 'rustiq_method': 4315}, 'circuit_entangling_depth': {'our_method': 2151, 'combined_method': 1454, 'qiskit_method': 2779, 'rustiq_method': 2079}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n13_layers3.json'}
# labs_n14_layers1.json
# {'num_paulis': 217, 'times': {'our_time': 32.283549547195435, 'combined_time': 31.002110481262207, 'qiskit_time': 0.6153573989868164, 'rustiq_time': 0.9147098064422607}, 'gate_counts': {'our_method': 1862, 'combined_method': 858, 'qiskit_method': 1791, 'rustiq_method': 2199}, 'circuit_entangling_depth': {'our_method': 901, 'combined_method': 563, 'qiskit_method': 1148, 'rustiq_method': 930}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n14_layers1.json'}
# labs_n14_layers3.json
# {'num_paulis': 651, 'times': {'our_time': 97.45466589927673, 'combined_time': 93.53426384925842, 'qiskit_time': 1.9779040813446045, 'rustiq_time': 2.7901699542999268}, 'gate_counts': {'our_method': 5247, 'combined_method': 2725, 'qiskit_method': 5601, 'rustiq_method': 6057}, 'circuit_entangling_depth': {'our_method': 2543, 'combined_method': 1710, 'qiskit_method': 3603, 'rustiq_method': 2856}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n14_layers3.json'}
# labs_n15_layers1.json
# {'num_paulis': 267, 'times': {'our_time': 50.523499727249146, 'combined_time': 51.438337087631226, 'qiskit_time': 1.2801814079284668, 'rustiq_time': 1.2302496433258057}, 'gate_counts': {'our_method': 2787, 'combined_method': 1274, 'qiskit_method': 2454, 'rustiq_method': 2931}, 'circuit_entangling_depth': {'our_method': 1295, 'combined_method': 778, 'qiskit_method': 1500, 'rustiq_method': 1273}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n15_layers1.json'}
# labs_n15_layers3.json
# {'num_paulis': 801, 'times': {'our_time': 158.2132556438446, 'combined_time': 157.70311641693115, 'qiskit_time': 2.8286736011505127, 'rustiq_time': 4.519832611083984}, 'gate_counts': {'our_method': 7783, 'combined_method': 3926, 'qiskit_method': 7649, 'rustiq_method': 8103}, 'circuit_entangling_depth': {'our_method': 3765, 'combined_method': 2457, 'qiskit_method': 4559, 'rustiq_method': 3901}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n15_layers3.json'}
# labs_n16_layers1.json
# {'num_paulis': 324, 'times': {'our_time': 89.1590576171875, 'combined_time': 84.26929783821106, 'qiskit_time': 1.1063659191131592, 'rustiq_time': 1.701493263244629}, 'gate_counts': {'our_method': 3455, 'combined_method': 1640, 'qiskit_method': 3102, 'rustiq_method': 3666}, 'circuit_entangling_depth': {'our_method': 1597, 'combined_method': 964, 'qiskit_method': 1927, 'rustiq_method': 1669}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n16_layers1.json'}
# labs_n16_layers3.json
# {'num_paulis': 972, 'times': {'our_time': 258.85318875312805, 'combined_time': 275.2273042201996, 'qiskit_time': 3.353052854537964, 'rustiq_time': 5.330010652542114}, 'gate_counts': {'our_method': 10207, 'combined_method': 5073, 'qiskit_method': 9467, 'rustiq_method': 10802}, 'circuit_entangling_depth': {'our_method': 4801, 'combined_method': 3010, 'qiskit_method': 5793, 'rustiq_method': 5016}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n16_layers3.json'}
# labs_n17_layers1.json
# {'num_paulis': 389, 'times': {'our_time': 129.7689597606659, 'combined_time': 121.26253914833069, 'qiskit_time': 1.4506278038024902, 'rustiq_time': 2.015674352645874}, 'gate_counts': {'our_method': 4566, 'combined_method': 2037, 'qiskit_method': 3738, 'rustiq_method': 4272}, 'circuit_entangling_depth': {'our_method': 2009, 'combined_method': 1226, 'qiskit_method': 2323, 'rustiq_method': 1891}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n17_layers1.json'}
# labs_n17_layers3.json
# {'num_paulis': 1167, 'times': {'our_time': 371.5358786582947, 'combined_time': 359.922238111496, 'qiskit_time': 4.1289472579956055, 'rustiq_time': 6.37086820602417}, 'gate_counts': {'our_method': 13402, 'combined_method': 6602, 'qiskit_method': 11508, 'rustiq_method': 13693}, 'circuit_entangling_depth': {'our_method': 6172, 'combined_method': 3858, 'qiskit_method': 7211, 'rustiq_method': 6224}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n17_layers3.json'}
# labs_n18_layers1.json
# {'num_paulis': 462, 'times': {'our_time': 176.96218252182007, 'combined_time': 177.255854845047, 'qiskit_time': 2.421649932861328, 'rustiq_time': 2.288372278213501}, 'gate_counts': {'our_method': 5457, 'combined_method': 2494, 'qiskit_method': 4435, 'rustiq_method': 5907}, 'circuit_entangling_depth': {'our_method': 2449, 'combined_method': 1455, 'qiskit_method': 2625, 'rustiq_method': 2395}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n18_layers1.json'}
# labs_n18_layers3.json
# {'num_paulis': 1386, 'times': {'our_time': 545.3689980506897, 'combined_time': 541.5908937454224, 'qiskit_time': 4.75935697555542, 'rustiq_time': 7.966130971908569}, 'gate_counts': {'our_method': 16700, 'combined_method': 8265, 'qiskit_method': 13565, 'rustiq_method': 18163}, 'circuit_entangling_depth': {'our_method': 7550, 'combined_method': 4830, 'qiskit_method': 7996, 'rustiq_method': 7964}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n18_layers3.json'}
# labs_n19_layers1.json
# {'num_paulis': 544, 'times': {'our_time': 264.9803547859192, 'combined_time': 263.68389105796814, 'qiskit_time': 1.9799308776855469, 'rustiq_time': 2.820979118347168}, 'gate_counts': {'our_method': 7572, 'combined_method': 3460, 'qiskit_method': 5414, 'rustiq_method': 7307}, 'circuit_entangling_depth': {'our_method': 3322, 'combined_method': 1919, 'qiskit_method': 3225, 'rustiq_method': 3065}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n19_layers1.json'}
# labs_n19_layers3.json
# {'num_paulis': 1632, 'times': {'our_time': 794.2192294597626, 'combined_time': 836.1950304508209, 'qiskit_time': 9.621718168258667, 'rustiq_time': 11.02342176437378}, 'gate_counts': {'our_method': 22280, 'combined_method': 10637, 'qiskit_method': 16674, 'rustiq_method': 23143}, 'circuit_entangling_depth': {'our_method': 10011, 'combined_method': 5952, 'qiskit_method': 9971, 'rustiq_method': 10009}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n19_layers3.json'}
# labs_n20_layers1.json
# {'num_paulis': 635, 'times': {'our_time': 391.09699630737305, 'combined_time': 388.1155951023102, 'qiskit_time': 3.663428544998169, 'rustiq_time': 3.6051530838012695}, 'gate_counts': {'our_method': 8454, 'combined_method': 3851, 'qiskit_method': 6485, 'rustiq_method': 8745}, 'circuit_entangling_depth': {'our_method': 3703, 'combined_method': 2138, 'qiskit_method': 3885, 'rustiq_method': 3628}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n20_layers1.json'}
# labs_n20_layers3.json
# {'num_paulis': 1905, 'times': {'our_time': 1168.8536131381989, 'combined_time': 1168.2400379180908, 'qiskit_time': 7.2443528175354, 'rustiq_time': 14.293890714645386}, 'gate_counts': {'our_method': 29274, 'combined_method': 14065, 'qiskit_method': 19936, 'rustiq_method': 29130}, 'circuit_entangling_depth': {'our_method': 13050, 'combined_method': 7946, 'qiskit_method': 11559, 'rustiq_method': 12602}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n20_layers3.json'}
# labs_n5_layers1.json
# {'num_paulis': 12, 'times': {'our_time': 0.15326499938964844, 'combined_time': 0.12171316146850586, 'qiskit_time': 0.04095101356506348, 'rustiq_time': 0.053856611251831055}, 'gate_counts': {'our_method': 47, 'combined_method': 23, 'qiskit_method': 29, 'rustiq_method': 48}, 'circuit_entangling_depth': {'our_method': 39, 'combined_method': 22, 'qiskit_method': 27, 'rustiq_method': 36}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n5_layers1.json'}
# labs_n5_layers3.json
# {'num_paulis': 36, 'times': {'our_time': 0.5017299652099609, 'combined_time': 0.38164687156677246, 'qiskit_time': 0.0747992992401123, 'rustiq_time': 0.10892224311828613}, 'gate_counts': {'our_method': 135, 'combined_method': 58, 'qiskit_method': 101, 'rustiq_method': 121}, 'circuit_entangling_depth': {'our_method': 104, 'combined_method': 51, 'qiskit_method': 95, 'rustiq_method': 97}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n5_layers3.json'}
# labs_n6_layers1.json
# {'num_paulis': 19, 'times': {'our_time': 0.4582693576812744, 'combined_time': 0.2485795021057129, 'qiskit_time': 0.06792306900024414, 'rustiq_time': 0.08583426475524902}, 'gate_counts': {'our_method': 99, 'combined_method': 34, 'qiskit_method': 64, 'rustiq_method': 92}, 'circuit_entangling_depth': {'our_method': 69, 'combined_method': 29, 'qiskit_method': 55, 'rustiq_method': 63}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n6_layers1.json'}
# labs_n6_layers3.json
# {'num_paulis': 57, 'times': {'our_time': 0.9638550281524658, 'combined_time': 0.7698838710784912, 'qiskit_time': 0.2737603187561035, 'rustiq_time': 0.16680335998535156}, 'gate_counts': {'our_method': 271, 'combined_method': 124, 'qiskit_method': 232, 'rustiq_method': 207}, 'circuit_entangling_depth': {'our_method': 188, 'combined_method': 106, 'qiskit_method': 188, 'rustiq_method': 139}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n6_layers3.json'}
# labs_n7_layers1.json
# {'num_paulis': 29, 'times': {'our_time': 0.6196975708007812, 'combined_time': 0.5527856349945068, 'qiskit_time': 0.08075261116027832, 'rustiq_time': 0.14182639122009277}, 'gate_counts': {'our_method': 205, 'combined_method': 63, 'qiskit_method': 125, 'rustiq_method': 228}, 'circuit_entangling_depth': {'our_method': 122, 'combined_method': 48, 'qiskit_method': 104, 'rustiq_method': 148}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n7_layers1.json'}
# labs_n7_layers3.json
# {'num_paulis': 87, 'times': {'our_time': 2.020124673843384, 'combined_time': 1.5897612571716309, 'qiskit_time': 0.40732455253601074, 'rustiq_time': 0.3246169090270996}, 'gate_counts': {'our_method': 532, 'combined_method': 191, 'qiskit_method': 395, 'rustiq_method': 525}, 'circuit_entangling_depth': {'our_method': 331, 'combined_method': 153, 'qiskit_method': 292, 'rustiq_method': 328}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n7_layers3.json'}
# labs_n8_layers1.json
# {'num_paulis': 42, 'times': {'our_time': 1.3090898990631104, 'combined_time': 1.0255627632141113, 'qiskit_time': 0.10595130920410156, 'rustiq_time': 0.1945781707763672}, 'gate_counts': {'our_method': 333, 'combined_method': 111, 'qiskit_method': 217, 'rustiq_method': 372}, 'circuit_entangling_depth': {'our_method': 175, 'combined_method': 88, 'qiskit_method': 148, 'rustiq_method': 199}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n8_layers1.json'}
# labs_n8_layers3.json
# {'num_paulis': 126, 'times': {'our_time': 3.8292157649993896, 'combined_time': 3.201875686645508, 'qiskit_time': 0.41685986518859863, 'rustiq_time': 0.45832014083862305}, 'gate_counts': {'our_method': 978, 'combined_method': 355, 'qiskit_method': 716, 'rustiq_method': 907}, 'circuit_entangling_depth': {'our_method': 551, 'combined_method': 289, 'qiskit_method': 497, 'rustiq_method': 525}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n8_layers3.json'}
# labs_n9_layers1.json
# {'num_paulis': 59, 'times': {'our_time': 2.351332664489746, 'combined_time': 2.0665688514709473, 'qiskit_time': 0.1466078758239746, 'rustiq_time': 0.4213113784790039}, 'gate_counts': {'our_method': 538, 'combined_method': 161, 'qiskit_method': 343, 'rustiq_method': 620}, 'circuit_entangling_depth': {'our_method': 277, 'combined_method': 126, 'qiskit_method': 233, 'rustiq_method': 305}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n9_layers1.json'}
# labs_n9_layers3.json
# {'num_paulis': 177, 'times': {'our_time': 7.070137977600098, 'combined_time': 6.424107074737549, 'qiskit_time': 0.4221501350402832, 'rustiq_time': 0.7523648738861084}, 'gate_counts': {'our_method': 1528, 'combined_method': 508, 'qiskit_method': 1062, 'rustiq_method': 1475}, 'circuit_entangling_depth': {'our_method': 828, 'combined_method': 357, 'qiskit_method': 692, 'rustiq_method': 763}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_labs_n9_layers3.json'}

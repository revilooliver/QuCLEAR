# %%
import re
import qiskit
import json
import time

import numpy as np
from typing import List
from qiskit import transpile
import time

from fast_generator import fc_tree_commute_recur_lookahead_fast

from benchmarks.UCCSD_entanglers import generate_UCCSD_entanglers
from circuit_generator import construct_qcc_circuit

import numpy as np
# from qiskit_ibm_runtime.fake_provider import FakeSherbrooke

from qiskit.transpiler import CouplingMap

# %%
#Compare json files in a specific folder
import os, json
def run_experiment_folder(folder_path = None, filename = None, save_output = False, threshold = 1):

    if filename == None:
        file_list = os.listdir(folder_path)
    else:
        file_list = [filename]
    # Iterate over all files in the folder
    for filename in file_list:
        # Check if the file is a JSON file
        if filename.endswith(".json"):
            results = []
            # Print the filename
            print(filename)
            with open(folder_path + '/' + filename, "r") as file:
                paulis = json.load(file)

            # Function to check if a string contains only 'I' characters
            def is_all_identity(pauli):
                return all(char == 'I' for char in pauli)

            # Filter the list to remove all identity Paulis
            test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
            test_params = [0.01 * i for i in range(len(test_paulis))]

            # Measure time for our method
            start_time = time.time()
            opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_recur_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, threshold=threshold)
            opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            our_time = end_time - start_time

            start_time = time.time()
            opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_recur_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, threshold=threshold)
            opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
            end_time = time.time()
            combined_time = end_time - start_time
        
            # Collect results
            result = {
                "num_paulis": len(test_paulis),
                "times": {
                    "our_time": our_time,
                    "combined_time": combined_time
                },
                "gate_counts": {
                    "our_method": opt_qc_f.count_ops().get('cx', 0),
                    "combined_method": opt_qiskit.count_ops().get('cx', 0)
                },
                "circuit_entangling_depth": {
                    "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
                    "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1)
                },
                "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_grid/test_new_' + filename
            }
            print(result)
            results.append(result)
            if save_output == True:
                # Save test_paulis to a separate JSON file
                with open(f'benchmarks/results_hardware_topology_ibm_grid/test_new_' + filename, 'w') as paulis_file:
                    json.dump([test_paulis, results], paulis_file, indent=4)

# %%
#Compare a given list of paulis
def run_experiment_paulis(test_paulis, test_params = None, save_output = False, threshold = 1, filename = "Paulis"):

    results = []

    def is_all_identity(pauli):
        return all(char == 'I' for char in pauli)
    paulis = test_paulis
    # Filter the list to remove all identity Paulis
    test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
    if test_params is None:
        test_params = [0.01 * i for i in range(len(test_paulis))]

    # Measure time for our method
    start_time = time.time()
    opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_recur_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, threshold=threshold)
    opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    our_time = end_time - start_time

    start_time = time.time()
    opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_recur_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, threshold=threshold)
    opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=CouplingMap().from_grid(11,11))
    end_time = time.time()
    combined_time = end_time - start_time
    
    # Collect results
    result = {
        "num_paulis": len(test_paulis),
        "times": {
            "our_time": our_time,
            "combined_time": combined_time
        },
        "gate_counts": {
            "our_method": opt_qc_f.count_ops().get('cx', 0),
            "combined_method": opt_qiskit.count_ops().get('cx', 0)
        },
        "circuit_entangling_depth": {
            "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
            "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1)
        },
        "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_grid/test_new_' + filename
    }
    print(result)
    results.append(result)
    if save_output == True:
        # Save test_paulis to a separate JSON file
        with open(f'benchmarks/results_hardware_topology_ibm_grid/test_new_' + filename, 'w') as paulis_file:
            json.dump([test_paulis, results], paulis_file, indent=4)
    return sorted_entanglers_f

# %%
#first compare the UCCSD ansatz
electrons_list = [2, 2, 4, 6, 8, 10,]# 12]
orbitals_list = [4, 6, 8, 12, 16, 20,]# 24]
#First evaluate the UCCSD ansatz:
for i, (x, y) in enumerate(zip(electrons_list, orbitals_list)):
    test_paulis = generate_UCCSD_entanglers(x, y)
    entanglers = run_experiment_paulis(test_paulis = test_paulis, save_output = True, threshold = 1, filename=f"Paulis{len(test_paulis)}.json")
# Out:
# {'num_paulis': 24, 'times': {'our_time': 0.26618003845214844, 'combined_time': 0.18530488014221191}, 'gate_counts': {'our_method': 75, 'combined_method': 26}, 'circuit_entangling_depth': {'our_method': 55, 'combined_method': 21}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis24.json'}
# {'num_paulis': 80, 'times': {'our_time': 1.125511884689331, 'combined_time': 0.6386773586273193}, 'gate_counts': {'our_method': 392, 'combined_method': 159}, 'circuit_entangling_depth': {'our_method': 284, 'combined_method': 115}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis80.json'}
# {'num_paulis': 320, 'times': {'our_time': 4.987126350402832, 'combined_time': 3.1851730346679688}, 'gate_counts': {'our_method': 1953, 'combined_method': 780}, 'circuit_entangling_depth': {'our_method': 1255, 'combined_method': 559}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis320.json'}
# {'num_paulis': 1656, 'times': {'our_time': 32.261802434921265, 'combined_time': 26.493900537490845}, 'gate_counts': {'our_method': 10273, 'combined_method': 5005}, 'circuit_entangling_depth': {'our_method': 6215, 'combined_method': 3381}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis1656.json'}
# {'num_paulis': 5376, 'times': {'our_time': 118.74239158630371, 'combined_time': 94.605717420578}, 'gate_counts': {'our_method': 40042, 'combined_method': 19911}, 'circuit_entangling_depth': {'our_method': 22562, 'combined_method': 12334}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis5376.json'}
# {'num_paulis': 13400, 'times': {'our_time': 378.97805094718933, 'combined_time': 321.6611661911011}, 'gate_counts': {'our_method': 134146, 'combined_method': 63222}, 'circuit_entangling_depth': {'our_method': 66165, 'combined_method': 34926}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_Paulis13400.json'}

# %%
#Then compare the Hamiltonian simulation paulis in HS_paulis folder
run_experiment_folder(folder_path = "benchmarks/HS_paulis", save_output = True, threshold = 1)
# Out:
# benzene.json
# {'num_paulis': 1254, 'times': {'our_time': 24.15445637702942, 'combined_time': 19.85309910774231}, 'gate_counts': {'our_method': 11866, 'combined_method': 6302}, 'circuit_entangling_depth': {'our_method': 6189, 'combined_method': 4189}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_benzene.json'}
# H2O.json
# {'num_paulis': 184, 'times': {'our_time': 2.4414782524108887, 'combined_time': 1.8510229587554932}, 'gate_counts': {'our_method': 1327, 'combined_method': 531}, 'circuit_entangling_depth': {'our_method': 801, 'combined_method': 395}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_H2O.json'}
# LiH.json
# {'num_paulis': 61, 'times': {'our_time': 0.6832056045532227, 'combined_time': 0.466752290725708}, 'gate_counts': {'our_method': 280, 'combined_method': 140}, 'circuit_entangling_depth': {'our_method': 202, 'combined_method': 125}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_LiH.json'}

# %%
#Then compare the MAXCUT paulis in max_cut_paulis folder

run_experiment_folder(folder_path = "benchmarks/max_cut_paulis", save_output = True, threshold = 1)
# Out:
# max_cut_benchmark_connected_n10_e12_l1.json
# {'num_paulis': 22, 'times': {'our_time': 0.4657871723175049, 'combined_time': 0.29920005798339844}, 'gate_counts': {'our_method': 275, 'combined_method': 47}, 'circuit_entangling_depth': {'our_method': 135, 'combined_method': 37}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n10_e12_l1.json'}
# max_cut_benchmark_connected_n10_e12_l3.json
# {'num_paulis': 66, 'times': {'our_time': 0.8587360382080078, 'combined_time': 0.7409992218017578}, 'gate_counts': {'our_method': 635, 'combined_method': 130}, 'circuit_entangling_depth': {'our_method': 313, 'combined_method': 81}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n10_e12_l3.json'}
# max_cut_benchmark_connected_n15_e63_l1.json
# {'num_paulis': 78, 'times': {'our_time': 3.8816189765930176, 'combined_time': 3.702141046524048}, 'gate_counts': {'our_method': 674, 'combined_method': 197}, 'circuit_entangling_depth': {'our_method': 295, 'combined_method': 120}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n15_e63_l1.json'}
# max_cut_benchmark_connected_n15_e63_l3.json
# {'num_paulis': 234, 'times': {'our_time': 10.541839122772217, 'combined_time': 13.921830892562866}, 'gate_counts': {'our_method': 1668, 'combined_method': 648}, 'circuit_entangling_depth': {'our_method': 667, 'combined_method': 378}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n15_e63_l3.json'}
# max_cut_benchmark_connected_n20_e117_l1.json
# {'num_paulis': 137, 'times': {'our_time': 15.231486082077026, 'combined_time': 14.009578466415405}, 'gate_counts': {'our_method': 1297, 'combined_method': 472}, 'circuit_entangling_depth': {'our_method': 465, 'combined_method': 249}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n20_e117_l1.json'}
# max_cut_benchmark_connected_n20_e117_l3.json
# {'num_paulis': 411, 'times': {'our_time': 40.75812315940857, 'combined_time': 40.718167304992676}, 'gate_counts': {'our_method': 3379, 'combined_method': 1373}, 'circuit_entangling_depth': {'our_method': 1210, 'combined_method': 618}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n20_e117_l3.json'}
# max_cut_benchmark_regular_n10_e3_l1.json
# {'num_paulis': 25, 'times': {'our_time': 0.4138906002044678, 'combined_time': 0.37998342514038086}, 'gate_counts': {'our_method': 312, 'combined_method': 64}, 'circuit_entangling_depth': {'our_method': 150, 'combined_method': 36}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n10_e3_l1.json'}
# max_cut_benchmark_regular_n10_e3_l3.json
# {'num_paulis': 75, 'times': {'our_time': 1.0282537937164307, 'combined_time': 0.9335055351257324}, 'gate_counts': {'our_method': 658, 'combined_method': 175}, 'circuit_entangling_depth': {'our_method': 295, 'combined_method': 111}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n10_e3_l3.json'}
# max_cut_benchmark_regular_n15_e4_l1.json
# {'num_paulis': 45, 'times': {'our_time': 1.525921106338501, 'combined_time': 5.255955696105957}, 'gate_counts': {'our_method': 490, 'combined_method': 156}, 'circuit_entangling_depth': {'our_method': 175, 'combined_method': 87}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n15_e4_l1.json'}
# max_cut_benchmark_regular_n15_e4_l3.json
# {'num_paulis': 135, 'times': {'our_time': 3.928500175476074, 'combined_time': 4.223713397979736}, 'gate_counts': {'our_method': 1338, 'combined_method': 500}, 'circuit_entangling_depth': {'our_method': 521, 'combined_method': 284}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n15_e4_l3.json'}
# max_cut_benchmark_regular_n20_e12_l1.json
# {'num_paulis': 140, 'times': {'our_time': 18.992291688919067, 'combined_time': 16.26549792289734}, 'gate_counts': {'our_method': 1410, 'combined_method': 513}, 'circuit_entangling_depth': {'our_method': 550, 'combined_method': 249}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e12_l1.json'}
# max_cut_benchmark_regular_n20_e12_l3.json
# {'num_paulis': 420, 'times': {'our_time': 47.62409281730652, 'combined_time': 48.897374629974365}, 'gate_counts': {'our_method': 4213, 'combined_method': 1628}, 'circuit_entangling_depth': {'our_method': 1515, 'combined_method': 767}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e12_l3.json'}
# max_cut_benchmark_regular_n20_e3_l1.json
# {'num_paulis': 50, 'times': {'our_time': 2.031571626663208, 'combined_time': 1.9607617855072021}, 'gate_counts': {'our_method': 446, 'combined_method': 108}, 'circuit_entangling_depth': {'our_method': 131, 'combined_method': 47}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e3_l1.json'}
# max_cut_benchmark_regular_n20_e3_l3.json
# {'num_paulis': 150, 'times': {'our_time': 5.488365173339844, 'combined_time': 5.233982563018799}, 'gate_counts': {'our_method': 1308, 'combined_method': 409}, 'circuit_entangling_depth': {'our_method': 402, 'combined_method': 165}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e3_l3.json'}
# max_cut_benchmark_regular_n20_e4_l1.json
# {'num_paulis': 60, 'times': {'our_time': 2.819465160369873, 'combined_time': 2.710756540298462}, 'gate_counts': {'our_method': 782, 'combined_method': 231}, 'circuit_entangling_depth': {'our_method': 253, 'combined_method': 104}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e4_l1.json'}
# max_cut_benchmark_regular_n20_e4_l3.json
# {'num_paulis': 180, 'times': {'our_time': 7.398263216018677, 'combined_time': 7.233640670776367}, 'gate_counts': {'our_method': 1989, 'combined_method': 702}, 'circuit_entangling_depth': {'our_method': 718, 'combined_method': 354}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e4_l3.json'}
# max_cut_benchmark_regular_n20_e8_l1.json
# {'num_paulis': 100, 'times': {'our_time': 7.973727703094482, 'combined_time': 8.1860933303833}, 'gate_counts': {'our_method': 1100, 'combined_method': 377}, 'circuit_entangling_depth': {'our_method': 393, 'combined_method': 180}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e8_l1.json'}
# max_cut_benchmark_regular_n20_e8_l3.json
# {'num_paulis': 300, 'times': {'our_time': 24.00984215736389, 'combined_time': 22.93671178817749}, 'gate_counts': {'our_method': 3297, 'combined_method': 1217}, 'circuit_entangling_depth': {'our_method': 1164, 'combined_method': 593}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e8_l3.json'}

# %%
#since in the maxcut problems there are many commuting terms and it's slow to search through all of them,
#we can set the threshold to 2 to early stop the search once found a simplified pauli of weight 2
#you can see the run time difference, for the second benchmark runtime reduces from 30second to 7 seconds.

run_experiment_folder(folder_path = "benchmarks/max_cut_paulis", save_output = True, threshold = 2)
# Out:
# max_cut_benchmark_connected_n10_e12_l1.json
# {'num_paulis': 22, 'times': {'our_time': 0.29023218154907227, 'combined_time': 0.22538995742797852}, 'gate_counts': {'our_method': 254, 'combined_method': 47}, 'circuit_entangling_depth': {'our_method': 125, 'combined_method': 34}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n10_e12_l1.json'}
# max_cut_benchmark_connected_n10_e12_l3.json
# {'num_paulis': 66, 'times': {'our_time': 0.7121310234069824, 'combined_time': 0.5943779945373535}, 'gate_counts': {'our_method': 554, 'combined_method': 120}, 'circuit_entangling_depth': {'our_method': 261, 'combined_method': 85}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n10_e12_l3.json'}
# max_cut_benchmark_connected_n15_e63_l1.json
# {'num_paulis': 78, 'times': {'our_time': 2.470388412475586, 'combined_time': 2.1392982006073}, 'gate_counts': {'our_method': 735, 'combined_method': 227}, 'circuit_entangling_depth': {'our_method': 309, 'combined_method': 135}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n15_e63_l1.json'}
# max_cut_benchmark_connected_n15_e63_l3.json
# {'num_paulis': 234, 'times': {'our_time': 6.567443132400513, 'combined_time': 5.9131999015808105}, 'gate_counts': {'our_method': 2022, 'combined_method': 699}, 'circuit_entangling_depth': {'our_method': 797, 'combined_method': 366}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n15_e63_l3.json'}
# max_cut_benchmark_connected_n20_e117_l1.json
# {'num_paulis': 137, 'times': {'our_time': 7.15590500831604, 'combined_time': 6.605316400527954}, 'gate_counts': {'our_method': 1145, 'combined_method': 455}, 'circuit_entangling_depth': {'our_method': 404, 'combined_method': 237}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n20_e117_l1.json'}
# max_cut_benchmark_connected_n20_e117_l3.json
# {'num_paulis': 411, 'times': {'our_time': 21.823718309402466, 'combined_time': 21.089614152908325}, 'gate_counts': {'our_method': 3743, 'combined_method': 1375}, 'circuit_entangling_depth': {'our_method': 1268, 'combined_method': 653}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_connected_n20_e117_l3.json'}
# max_cut_benchmark_regular_n10_e3_l1.json
# {'num_paulis': 25, 'times': {'our_time': 0.3102090358734131, 'combined_time': 0.2762570381164551}, 'gate_counts': {'our_method': 305, 'combined_method': 67}, 'circuit_entangling_depth': {'our_method': 134, 'combined_method': 37}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n10_e3_l1.json'}
# max_cut_benchmark_regular_n10_e3_l3.json
# {'num_paulis': 75, 'times': {'our_time': 0.8377611637115479, 'combined_time': 0.8387589454650879}, 'gate_counts': {'our_method': 714, 'combined_method': 191}, 'circuit_entangling_depth': {'our_method': 320, 'combined_method': 119}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n10_e3_l3.json'}
# max_cut_benchmark_regular_n15_e4_l1.json
# {'num_paulis': 45, 'times': {'our_time': 0.975426435470581, 'combined_time': 0.9045512676239014}, 'gate_counts': {'our_method': 530, 'combined_method': 157}, 'circuit_entangling_depth': {'our_method': 188, 'combined_method': 89}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n15_e4_l1.json'}
# max_cut_benchmark_regular_n15_e4_l3.json
# {'num_paulis': 135, 'times': {'our_time': 3.062817096710205, 'combined_time': 2.5950982570648193}, 'gate_counts': {'our_method': 1375, 'combined_method': 473}, 'circuit_entangling_depth': {'our_method': 524, 'combined_method': 247}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n15_e4_l3.json'}
# max_cut_benchmark_regular_n20_e12_l1.json
# {'num_paulis': 140, 'times': {'our_time': 7.7722320556640625, 'combined_time': 7.19776725769043}, 'gate_counts': {'our_method': 1429, 'combined_method': 542}, 'circuit_entangling_depth': {'our_method': 547, 'combined_method': 276}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e12_l1.json'}
# max_cut_benchmark_regular_n20_e12_l3.json
# {'num_paulis': 420, 'times': {'our_time': 22.47394847869873, 'combined_time': 21.611284017562866}, 'gate_counts': {'our_method': 4121, 'combined_method': 1652}, 'circuit_entangling_depth': {'our_method': 1458, 'combined_method': 854}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e12_l3.json'}
# max_cut_benchmark_regular_n20_e3_l1.json
# {'num_paulis': 50, 'times': {'our_time': 1.5030183792114258, 'combined_time': 1.3084702491760254}, 'gate_counts': {'our_method': 464, 'combined_method': 109}, 'circuit_entangling_depth': {'our_method': 159, 'combined_method': 53}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e3_l1.json'}
# max_cut_benchmark_regular_n20_e3_l3.json
# {'num_paulis': 150, 'times': {'our_time': 3.5495147705078125, 'combined_time': 3.548560380935669}, 'gate_counts': {'our_method': 1194, 'combined_method': 334}, 'circuit_entangling_depth': {'our_method': 335, 'combined_method': 115}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e3_l3.json'}
# max_cut_benchmark_regular_n20_e4_l1.json
# {'num_paulis': 60, 'times': {'our_time': 1.7932100296020508, 'combined_time': 1.818173885345459}, 'gate_counts': {'our_method': 756, 'combined_method': 223}, 'circuit_entangling_depth': {'our_method': 249, 'combined_method': 104}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e4_l1.json'}
# max_cut_benchmark_regular_n20_e4_l3.json
# {'num_paulis': 180, 'times': {'our_time': 5.353726863861084, 'combined_time': 4.993624210357666}, 'gate_counts': {'our_method': 2071, 'combined_method': 703}, 'circuit_entangling_depth': {'our_method': 693, 'combined_method': 322}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e4_l3.json'}
# max_cut_benchmark_regular_n20_e8_l1.json
# {'num_paulis': 100, 'times': {'our_time': 4.302521705627441, 'combined_time': 4.134920358657837}, 'gate_counts': {'our_method': 1020, 'combined_method': 386}, 'circuit_entangling_depth': {'our_method': 358, 'combined_method': 168}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e8_l1.json'}
# max_cut_benchmark_regular_n20_e8_l3.json
# {'num_paulis': 300, 'times': {'our_time': 13.292500734329224, 'combined_time': 12.68510127067566}, 'gate_counts': {'our_method': 3140, 'combined_method': 1297}, 'circuit_entangling_depth': {'our_method': 1054, 'combined_method': 617}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_max_cut_benchmark_regular_n20_e8_l3.json'}

# %%
#Labs

run_experiment_folder(folder_path = "benchmarks/labs_paulis", save_output = True, threshold= 2)
# Out:
# labs_n10_layers1.json
# {'num_paulis': 80, 'times': {'our_time': 1.631622314453125, 'combined_time': 1.6366586685180664}, 'gate_counts': {'our_method': 814, 'combined_method': 261}, 'circuit_entangling_depth': {'our_method': 440, 'combined_method': 199}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n10_layers1.json'}
# labs_n10_layers3.json
# {'num_paulis': 240, 'times': {'our_time': 4.797212600708008, 'combined_time': 3.7140450477600098}, 'gate_counts': {'our_method': 2285, 'combined_method': 739}, 'circuit_entangling_depth': {'our_method': 1162, 'combined_method': 523}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n10_layers3.json'}
# labs_n11_layers1.json
# {'num_paulis': 106, 'times': {'our_time': 2.9770455360412598, 'combined_time': 2.518239736557007}, 'gate_counts': {'our_method': 1133, 'combined_method': 351}, 'circuit_entangling_depth': {'our_method': 562, 'combined_method': 258}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n11_layers1.json'}
# labs_n11_layers3.json
# {'num_paulis': 318, 'times': {'our_time': 8.471394300460815, 'combined_time': 7.229681491851807}, 'gate_counts': {'our_method': 3215, 'combined_method': 1055}, 'circuit_entangling_depth': {'our_method': 1605, 'combined_method': 732}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n11_layers3.json'}
# labs_n12_layers1.json
# {'num_paulis': 137, 'times': {'our_time': 4.735377788543701, 'combined_time': 4.337379455566406}, 'gate_counts': {'our_method': 1134, 'combined_method': 509}, 'circuit_entangling_depth': {'our_method': 535, 'combined_method': 350}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n12_layers1.json'}
# labs_n12_layers3.json
# {'num_paulis': 411, 'times': {'our_time': 14.448424816131592, 'combined_time': 13.028156042098999}, 'gate_counts': {'our_method': 2961, 'combined_method': 1498}, 'circuit_entangling_depth': {'our_method': 1530, 'combined_method': 1000}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n12_layers3.json'}
# labs_n13_layers1.json
# {'num_paulis': 174, 'times': {'our_time': 8.398559808731079, 'combined_time': 7.479015588760376}, 'gate_counts': {'our_method': 1500, 'combined_method': 657}, 'circuit_entangling_depth': {'our_method': 718, 'combined_method': 454}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n13_layers1.json'}
# labs_n13_layers3.json
# {'num_paulis': 522, 'times': {'our_time': 29.774438858032227, 'combined_time': 28.43602705001831}, 'gate_counts': {'our_method': 4322, 'combined_method': 2197}, 'circuit_entangling_depth': {'our_method': 2174, 'combined_method': 1383}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n13_layers3.json'}
# labs_n14_layers1.json
# {'num_paulis': 217, 'times': {'our_time': 13.624627351760864, 'combined_time': 12.736933946609497}, 'gate_counts': {'our_method': 1955, 'combined_method': 922}, 'circuit_entangling_depth': {'our_method': 903, 'combined_method': 551}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n14_layers1.json'}
# labs_n14_layers3.json
# {'num_paulis': 651, 'times': {'our_time': 46.104838848114014, 'combined_time': 44.850157499313354}, 'gate_counts': {'our_method': 5652, 'combined_method': 2910}, 'circuit_entangling_depth': {'our_method': 2688, 'combined_method': 1825}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n14_layers3.json'}
# labs_n15_layers1.json
# {'num_paulis': 267, 'times': {'our_time': 20.301781177520752, 'combined_time': 19.845942735671997}, 'gate_counts': {'our_method': 2644, 'combined_method': 1207}, 'circuit_entangling_depth': {'our_method': 1252, 'combined_method': 740}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n15_layers1.json'}
# labs_n15_layers3.json
# {'num_paulis': 801, 'times': {'our_time': 67.57144474983215, 'combined_time': 66.18714356422424}, 'gate_counts': {'our_method': 7136, 'combined_method': 3608}, 'circuit_entangling_depth': {'our_method': 3379, 'combined_method': 2158}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n15_layers3.json'}
# labs_n16_layers1.json
# {'num_paulis': 324, 'times': {'our_time': 35.908084869384766, 'combined_time': 34.90070915222168}, 'gate_counts': {'our_method': 3261, 'combined_method': 1527}, 'circuit_entangling_depth': {'our_method': 1530, 'combined_method': 926}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n16_layers1.json'}
# labs_n16_layers3.json
# {'num_paulis': 972, 'times': {'our_time': 123.67438435554504, 'combined_time': 134.74694919586182}, 'gate_counts': {'our_method': 9935, 'combined_method': 4844}, 'circuit_entangling_depth': {'our_method': 4595, 'combined_method': 3012}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n16_layers3.json'}
# labs_n17_layers1.json
# {'num_paulis': 389, 'times': {'our_time': 55.09897994995117, 'combined_time': 53.344359397888184}, 'gate_counts': {'our_method': 3976, 'combined_method': 1938}, 'circuit_entangling_depth': {'our_method': 1829, 'combined_method': 1137}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n17_layers1.json'}
# labs_n17_layers3.json
# {'num_paulis': 1167, 'times': {'our_time': 257.98183488845825, 'combined_time': 262.3782277107239}, 'gate_counts': {'our_method': 12558, 'combined_method': 6024}, 'circuit_entangling_depth': {'our_method': 5741, 'combined_method': 3488}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n17_layers3.json'}
# labs_n18_layers1.json
# {'num_paulis': 462, 'times': {'our_time': 115.63281536102295, 'combined_time': 108.6073317527771}, 'gate_counts': {'our_method': 5568, 'combined_method': 2447}, 'circuit_entangling_depth': {'our_method': 2472, 'combined_method': 1406}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n18_layers1.json'}
# labs_n18_layers3.json
# {'num_paulis': 1386, 'times': {'our_time': 384.92686462402344, 'combined_time': 299.0699510574341}, 'gate_counts': {'our_method': 15912, 'combined_method': 7623}, 'circuit_entangling_depth': {'our_method': 7096, 'combined_method': 4238}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n18_layers3.json'}
# labs_n19_layers1.json
# {'num_paulis': 544, 'times': {'our_time': 132.70404148101807, 'combined_time': 129.5863709449768}, 'gate_counts': {'our_method': 6737, 'combined_method': 3097}, 'circuit_entangling_depth': {'our_method': 2916, 'combined_method': 1722}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n19_layers1.json'}
# labs_n19_layers3.json
# {'num_paulis': 1632, 'times': {'our_time': 379.5243413448334, 'combined_time': 383.98360800743103}, 'gate_counts': {'our_method': 19603, 'combined_method': 9376}, 'circuit_entangling_depth': {'our_method': 8749, 'combined_method': 5249}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n19_layers3.json'}
# labs_n20_layers1.json
# {'num_paulis': 635, 'times': {'our_time': 189.6610496044159, 'combined_time': 186.71129250526428}, 'gate_counts': {'our_method': 8843, 'combined_method': 3845}, 'circuit_entangling_depth': {'our_method': 3873, 'combined_method': 2251}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n20_layers1.json'}
# labs_n20_layers3.json
# {'num_paulis': 1905, 'times': {'our_time': 660.0670263767242, 'combined_time': 652.0267102718353}, 'gate_counts': {'our_method': 26347, 'combined_method': 12369}, 'circuit_entangling_depth': {'our_method': 11685, 'combined_method': 6786}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n20_layers3.json'}
# labs_n5_layers1.json
# {'num_paulis': 12, 'times': {'our_time': 0.11966633796691895, 'combined_time': 0.09577775001525879}, 'gate_counts': {'our_method': 42, 'combined_method': 19}, 'circuit_entangling_depth': {'our_method': 32, 'combined_method': 17}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n5_layers1.json'}
# labs_n5_layers3.json
# {'num_paulis': 36, 'times': {'our_time': 0.2882533073425293, 'combined_time': 0.19148802757263184}, 'gate_counts': {'our_method': 120, 'combined_method': 63}, 'circuit_entangling_depth': {'our_method': 93, 'combined_method': 54}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n5_layers3.json'}
# labs_n6_layers1.json
# {'num_paulis': 19, 'times': {'our_time': 0.17751145362854004, 'combined_time': 0.1406543254852295}, 'gate_counts': {'our_method': 105, 'combined_method': 37}, 'circuit_entangling_depth': {'our_method': 71, 'combined_method': 26}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n6_layers1.json'}
# labs_n6_layers3.json
# {'num_paulis': 57, 'times': {'our_time': 0.5824296474456787, 'combined_time': 0.3251008987426758}, 'gate_counts': {'our_method': 232, 'combined_method': 94}, 'circuit_entangling_depth': {'our_method': 155, 'combined_method': 71}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n6_layers3.json'}
# labs_n7_layers1.json
# {'num_paulis': 29, 'times': {'our_time': 0.3281223773956299, 'combined_time': 0.24837589263916016}, 'gate_counts': {'our_method': 204, 'combined_method': 67}, 'circuit_entangling_depth': {'our_method': 118, 'combined_method': 58}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n7_layers1.json'}
# labs_n7_layers3.json
# {'num_paulis': 87, 'times': {'our_time': 0.9853701591491699, 'combined_time': 0.6223404407501221}, 'gate_counts': {'our_method': 585, 'combined_method': 190}, 'circuit_entangling_depth': {'our_method': 344, 'combined_method': 179}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n7_layers3.json'}
# labs_n8_layers1.json
# {'num_paulis': 42, 'times': {'our_time': 0.5216054916381836, 'combined_time': 0.38294386863708496}, 'gate_counts': {'our_method': 302, 'combined_method': 96}, 'circuit_entangling_depth': {'our_method': 167, 'combined_method': 83}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n8_layers1.json'}
# labs_n8_layers3.json
# {'num_paulis': 126, 'times': {'our_time': 1.5209338665008545, 'combined_time': 1.1768574714660645}, 'gate_counts': {'our_method': 869, 'combined_method': 333}, 'circuit_entangling_depth': {'our_method': 508, 'combined_method': 259}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n8_layers3.json'}
# labs_n9_layers1.json
# {'num_paulis': 59, 'times': {'our_time': 0.861670732498169, 'combined_time': 0.696108341217041}, 'gate_counts': {'our_method': 556, 'combined_method': 161}, 'circuit_entangling_depth': {'our_method': 282, 'combined_method': 130}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n9_layers1.json'}
# labs_n9_layers3.json
# {'num_paulis': 177, 'times': {'our_time': 2.823483467102051, 'combined_time': 2.1412782669067383}, 'gate_counts': {'our_method': 1480, 'combined_method': 513}, 'circuit_entangling_depth': {'our_method': 805, 'combined_method': 388}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_grid/test_new_labs_n9_layers3.json'}

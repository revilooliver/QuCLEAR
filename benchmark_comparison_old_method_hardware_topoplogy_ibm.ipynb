# %%
import re
import qiskit
import json
import time
import os
import numpy as np
from qiskit import transpile, QuantumCircuit
import time

from fast_generator import fc_tree_commute_lookahead_fast
from benchmarks.UCCSD_entanglers import generate_UCCSD_entanglers
from circuit_generator import construct_qcc_circuit

import numpy as np
from rustiq import pauli_network_synthesis, Metric
from rustiq.utils import entangling_count, entangling_depth
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
import rustiq

# %%
def convert_to_circuit(circuit: list) -> QuantumCircuit:
    """
    Converts a circuit into a CNOT + H + S + RZ(theta) to a quantumcircuit
    """
    num_qubits=len(set([num for op in circuit for num in op[1]]))
    new_circuit=QuantumCircuit(num_qubits)
    for gate in circuit:
        op=gate[0]
        params=gate[1]
        assert op in ["CNOT", "CZ", "H", "S", "Sd", "X", "Z", "SqrtX", "SqrtXd"], f"op not allowed {op}"
        if op=="CNOT":
            new_circuit.cx(params[0], params[1])
        elif op=="CZ":
            new_circuit.cz(params[0], params[1])
        elif op=="H":
            new_circuit.h(params[0])
        elif op=="S":
            new_circuit.s(params[0])
        elif op=="Sd":
            new_circuit.sdg(params[0])
        elif op=="X":
            new_circuit.x(params[0])
        elif op=="Z":
            new_circuit.z(params[0])
        elif op=="SqrtX":
            new_circuit.sx(params[0])
        elif op=="SqrtXd":
            new_circuit.sxdg(params[0])
    return new_circuit

# %%
#Compare json files in a specific folder
def run_experiment_folder(folder_path = None, filename = None, save_output = False, lookahead_size = 5):

    if filename == None:
        file_list = os.listdir(folder_path)
    else:
        file_list = [filename]
    # Iterate over all files in the folder
    for filename in file_list:
        # Check if the file is a JSON file
        if filename.endswith(".json"):
            results = []
            # Print the filename
            print(filename)
            with open(folder_path + '/' + filename, "r") as file:
                paulis = json.load(file)

            # Function to check if a string contains only 'I' characters
            def is_all_identity(pauli):
                return all(char == 'I' for char in pauli)

            # Filter the list to remove all identity Paulis
            test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
            test_params = [0.01 * i for i in range(len(test_paulis))]

            # Measure time for our method
            start_time = time.time()
            opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
            opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
            end_time = time.time()
            our_time = end_time - start_time

            start_time = time.time()
            opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
            opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
            end_time = time.time()
            combined_time = end_time - start_time
            
            # Measure time for Qiskit method
            start_time = time.time()
            origin_qc = construct_qcc_circuit(entanglers=test_paulis, params=test_params, barrier=False)
            origin_qiskit = transpile(origin_qc, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
            end_time = time.time()
            qiskit_time = end_time - start_time

            # Measure time for RustiQ method
            start_time = time.time()
            circuit = pauli_network_synthesis(test_paulis, Metric.COUNT, True, fix_clifford=True)
            qiskit_circ_rustiq=convert_to_circuit(circuit)
            # print(qiskit_circ_rustiq)
            # can't optimize with level 3 since rustiq returns an optimized circuit missing some single qubit gates.
            qiskit_circ_rustiq = transpile(qiskit_circ_rustiq, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
            end_time = time.time()
            rustiq_time = end_time - start_time
        
            # Collect results
            result = {
                "num_paulis": len(test_paulis),
                "times": {
                    "our_time": our_time,
                    "combined_time": combined_time,
                    "qiskit_time": qiskit_time,
                    "rustiq_time": rustiq_time
                },
                "gate_counts": {
                    "our_method": opt_qc_f.count_ops().get('cx', 0),
                    "combined_method": opt_qiskit.count_ops().get('cx', 0),
                    "qiskit_method": origin_qiskit.count_ops().get('cx', 0),
                    "rustiq_method": qiskit_circ_rustiq.count_ops().get('cx', 0)
                },
                "circuit_entangling_depth": {
                    "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
                    "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1),
                    "qiskit_method": origin_qiskit.depth(lambda instr: len(instr.qubits) > 1),
                    "rustiq_method": qiskit_circ_rustiq.depth(lambda instr: len(instr.qubits) > 1)
                },
                "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_sherbrooke/test_' + filename
            }
            print(result)
            results.append(result)
            if save_output == True:
                # Save test_paulis to a separate JSON file
                with open(f'benchmarks/results_hardware_topology_ibm_sherbrooke/test_' + filename, 'w') as paulis_file:
                    json.dump([test_paulis, results], paulis_file, indent=4)

# %%
#Compare a given list of paulis
def run_experiment_paulis(test_paulis, test_params = None, save_output = False, lookahead_size = 5, filename = "Paulis"):

    results = []

    def is_all_identity(pauli):
        return all(char == 'I' for char in pauli)
    paulis = test_paulis
    # Filter the list to remove all identity Paulis
    test_paulis = [pauli for pauli in paulis if not is_all_identity(pauli)]
    if test_params is None:
        test_params = [0.01 * i for i in range(len(test_paulis))]

    # Measure time for our method
    start_time = time.time()
    opt_qc_f, append_clifford_f, sorted_entanglers_f = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
    opt_qc_f = transpile(opt_qc_f, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
    end_time = time.time()
    our_time = end_time - start_time

    start_time = time.time()
    opt_qc_f2, append_clifford_f2, sorted_entanglers_f2 = fc_tree_commute_lookahead_fast(entanglers=test_paulis, params=test_params, barrier=False, lookahead_size=lookahead_size)
    opt_qiskit = transpile(opt_qc_f2, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
    end_time = time.time()
    combined_time = end_time - start_time
    
    # Measure time for Qiskit method
    start_time = time.time()
    origin_qc = construct_qcc_circuit(entanglers=test_paulis, params=test_params, barrier=False)
    origin_qiskit = transpile(origin_qc, optimization_level=3, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
    end_time = time.time()
    qiskit_time = end_time - start_time

    # Measure time for RustiQ method
    start_time = time.time()
    circuit = pauli_network_synthesis(test_paulis, Metric.COUNT, True, fix_clifford=True)
    qiskit_circ_rustiq=convert_to_circuit(circuit)
    # print(qiskit_circ_rustiq)
    # can't optimize with level 3 since rustiq returns an optimized circuit missing some single qubit gates.
    qiskit_circ_rustiq = transpile(qiskit_circ_rustiq, optimization_level=0, basis_gates=["cx", "sx", "x", "rz"], coupling_map=FakeSherbrooke().coupling_map)
    end_time = time.time()
    rustiq_time = end_time - start_time
    
    # Collect results
    result = {
        "num_paulis": len(test_paulis),
        "times": {
            "our_time": our_time,
            "combined_time": combined_time,
            "qiskit_time": qiskit_time,
            "rustiq_time": rustiq_time
        },
        "gate_counts": {
            "our_method": opt_qc_f.count_ops().get('cx', 0),
            "combined_method": opt_qiskit.count_ops().get('cx', 0),
            "qiskit_method": origin_qiskit.count_ops().get('cx', 0),
            "rustiq_method": qiskit_circ_rustiq.count_ops().get('cx', 0)
        },
        "circuit_entangling_depth": {
            "our_method": opt_qc_f.depth(lambda instr: len(instr.qubits) > 1),
            "combined_method": opt_qiskit.depth(lambda instr: len(instr.qubits) > 1),
            "qiskit_method": origin_qiskit.depth(lambda instr: len(instr.qubits) > 1),
            "rustiq_method": qiskit_circ_rustiq.depth(lambda instr: len(instr.qubits) > 1)
        },
        "test_paulis_file": f'benchmarks/results_hardware_topology_ibm_sherbrooke/test_' + filename
    }
    print(result)
    results.append(result)
    if save_output == True:
        # Save test_paulis to a separate JSON file
        with open(f'benchmarks/results_hardware_topology_ibm_sherbrooke/test_' + filename, 'w') as paulis_file:
            json.dump([test_paulis, results], paulis_file, indent=4)
    return sorted_entanglers_f

# %%
#first compare the UCCSD ansatz
electrons_list = [2, 2, 4, 6, 8, 10,] #12]
orbitals_list = [4, 6, 8, 12, 16, 20,] #24]
#First evaluate the UCCSD ansatz:
for i, (x, y) in enumerate(zip(electrons_list, orbitals_list)):
    test_paulis = generate_UCCSD_entanglers(x, y)
    entanglers = run_experiment_paulis(test_paulis = test_paulis, save_output = True, lookahead_size = 5, filename=f"Paulis{len(test_paulis)}.json")
# Out:
# {'num_paulis': 24, 'times': {'our_time': 0.6323122978210449, 'combined_time': 0.5844371318817139, 'qiskit_time': 0.5355696678161621, 'rustiq_time': 0.3919508457183838}, 'gate_counts': {'our_method': 60, 'combined_method': 45, 'qiskit_method': 35, 'rustiq_method': 81}, 'circuit_entangling_depth': {'our_method': 51, 'combined_method': 45, 'qiskit_method': 35, 'rustiq_method': 71}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis24.json'}
# {'num_paulis': 80, 'times': {'our_time': 2.4245223999023438, 'combined_time': 1.6688768863677979, 'qiskit_time': 2.332765579223633, 'rustiq_time': 1.3932769298553467}, 'gate_counts': {'our_method': 412, 'combined_method': 218, 'qiskit_method': 158, 'rustiq_method': 635}, 'circuit_entangling_depth': {'our_method': 293, 'combined_method': 179, 'qiskit_method': 146, 'rustiq_method': 463}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis80.json'}
# {'num_paulis': 320, 'times': {'our_time': 7.579745769500732, 'combined_time': 6.496639728546143, 'qiskit_time': 7.015254497528076, 'rustiq_time': 5.132285118103027}, 'gate_counts': {'our_method': 2550, 'combined_method': 1356, 'qiskit_method': 951, 'rustiq_method': 4149}, 'circuit_entangling_depth': {'our_method': 1616, 'combined_method': 1046, 'qiskit_method': 830, 'rustiq_method': 2598}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis320.json'}
# {'num_paulis': 1656, 'times': {'our_time': 43.464855670928955, 'combined_time': 43.64437532424927, 'qiskit_time': 86.07399415969849, 'rustiq_time': 79.99110674858093}, 'gate_counts': {'our_method': 18432, 'combined_method': 9710, 'qiskit_method': 7035, 'rustiq_method': 32494}, 'circuit_entangling_depth': {'our_method': 9671, 'combined_method': 6165, 'qiskit_method': 5807, 'rustiq_method': 17313}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis1656.json'}
# {'num_paulis': 5376, 'times': {'our_time': 341.1578917503357, 'combined_time': 227.6374650001526, 'qiskit_time': 704.7360198497772, 'rustiq_time': 1295.4465312957764}, 'gate_counts': {'our_method': 69281, 'combined_method': 42090, 'qiskit_method': 31899, 'rustiq_method': 130199}, 'circuit_entangling_depth': {'our_method': 34689, 'combined_method': 24276, 'qiskit_method': 28048, 'rustiq_method': 64222}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis5376.json'}
# {'num_paulis': 13400, 'times': {'our_time': 906.8696014881134, 'combined_time': 733.0852344036102, 'qiskit_time': 2122.5800092220306, 'rustiq_time': 17277.619384765625}, 'gate_counts': {'our_method': 228330, 'combined_method': 144046, 'qiskit_method': 99741, 'rustiq_method': 376825}, 'circuit_entangling_depth': {'our_method': 103993, 'combined_method': 74169, 'qiskit_method': 88757, 'rustiq_method': 175588}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_Paulis13400.json'}

# %%
#Then compare the Hamiltonian simulation paulis in HS_paulis folder
run_experiment_folder(folder_path = "benchmarks/HS_paulis", save_output = True, lookahead_size = 10)
# Out:
# benzene.json
# {'num_paulis': 1254, 'times': {'our_time': 77.63953351974487, 'combined_time': 69.28485894203186, 'qiskit_time': 72.77652978897095, 'rustiq_time': 52.082826137542725}, 'gate_counts': {'our_method': 31390, 'combined_method': 16638, 'qiskit_method': 9079, 'rustiq_method': 27526}, 'circuit_entangling_depth': {'our_method': 14709, 'combined_method': 10185, 'qiskit_method': 7562, 'rustiq_method': 13579}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_benzene.json'}
# H2O.json
# {'num_paulis': 184, 'times': {'our_time': 7.966710090637207, 'combined_time': 5.32078218460083, 'qiskit_time': 6.745974779129028, 'rustiq_time': 5.242988109588623}, 'gate_counts': {'our_method': 1632, 'combined_method': 887, 'qiskit_method': 1099, 'rustiq_method': 1867}, 'circuit_entangling_depth': {'our_method': 924, 'combined_method': 684, 'qiskit_method': 873, 'rustiq_method': 1112}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_H2O.json'}
# LiH.json
# {'num_paulis': 61, 'times': {'our_time': 2.31980037689209, 'combined_time': 1.4660828113555908, 'qiskit_time': 1.6156845092773438, 'rustiq_time': 1.7922091484069824}, 'gate_counts': {'our_method': 285, 'combined_method': 182, 'qiskit_method': 217, 'rustiq_method': 518}, 'circuit_entangling_depth': {'our_method': 205, 'combined_method': 166, 'qiskit_method': 201, 'rustiq_method': 339}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_LiH.json'}

# %%
#Then compare the MAXCUT paulis in max_cut_paulis folder

run_experiment_folder(folder_path = "benchmarks/max_cut_paulis", save_output = True, lookahead_size = 10)
# Out:
# max_cut_benchmark_connected_n10_e12_l1.json
# {'num_paulis': 22, 'times': {'our_time': 0.8876297473907471, 'combined_time': 0.782907247543335, 'qiskit_time': 0.47074103355407715, 'rustiq_time': 0.4697449207305908}, 'gate_counts': {'our_method': 255, 'combined_method': 71, 'qiskit_method': 30, 'rustiq_method': 201}, 'circuit_entangling_depth': {'our_method': 128, 'combined_method': 49, 'qiskit_method': 16, 'rustiq_method': 99}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n10_e12_l1.json'}
# max_cut_benchmark_connected_n10_e12_l3.json
# {'num_paulis': 66, 'times': {'our_time': 2.539215087890625, 'combined_time': 2.2340285778045654, 'qiskit_time': 0.5116331577301025, 'rustiq_time': 0.99234938621521}, 'gate_counts': {'our_method': 641, 'combined_method': 263, 'qiskit_method': 138, 'rustiq_method': 545}, 'circuit_entangling_depth': {'our_method': 290, 'combined_method': 171, 'qiskit_method': 70, 'rustiq_method': 247}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n10_e12_l3.json'}
# max_cut_benchmark_connected_n15_e63_l1.json
# {'num_paulis': 78, 'times': {'our_time': 6.075765371322632, 'combined_time': 5.749635219573975, 'qiskit_time': 0.8666844367980957, 'rustiq_time': 1.4670796394348145}, 'gate_counts': {'our_method': 1117, 'combined_method': 347, 'qiskit_method': 300, 'rustiq_method': 1302}, 'circuit_entangling_depth': {'our_method': 467, 'combined_method': 201, 'qiskit_method': 106, 'rustiq_method': 527}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n15_e63_l1.json'}
# max_cut_benchmark_connected_n15_e63_l3.json
# {'num_paulis': 234, 'times': {'our_time': 17.77250909805298, 'combined_time': 17.43441128730774, 'qiskit_time': 2.0215981006622314, 'rustiq_time': 3.0089590549468994}, 'gate_counts': {'our_method': 2945, 'combined_method': 1089, 'qiskit_method': 1053, 'rustiq_method': 2759}, 'circuit_entangling_depth': {'our_method': 1138, 'combined_method': 630, 'qiskit_method': 371, 'rustiq_method': 1104}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n15_e63_l3.json'}
# max_cut_benchmark_connected_n20_e117_l1.json
# {'num_paulis': 137, 'times': {'our_time': 19.38520050048828, 'combined_time': 19.588655710220337, 'qiskit_time': 1.4780511856079102, 'rustiq_time': 2.0096287727355957}, 'gate_counts': {'our_method': 1979, 'combined_method': 862, 'qiskit_method': 709, 'rustiq_method': 1910}, 'circuit_entangling_depth': {'our_method': 674, 'combined_method': 390, 'qiskit_method': 256, 'rustiq_method': 623}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n20_e117_l1.json'}
# max_cut_benchmark_connected_n20_e117_l3.json
# {'num_paulis': 411, 'times': {'our_time': 64.56447410583496, 'combined_time': 60.451462268829346, 'qiskit_time': 4.045192718505859, 'rustiq_time': 6.201426982879639}, 'gate_counts': {'our_method': 4964, 'combined_method': 2737, 'qiskit_method': 2418, 'rustiq_method': 5150}, 'circuit_entangling_depth': {'our_method': 1749, 'combined_method': 1283, 'qiskit_method': 842, 'rustiq_method': 2004}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_connected_n20_e117_l3.json'}
# max_cut_benchmark_regular_n10_e3_l1.json
# {'num_paulis': 25, 'times': {'our_time': 1.1409525871276855, 'combined_time': 7.108006715774536, 'qiskit_time': 0.49268198013305664, 'rustiq_time': 0.5634951591491699}, 'gate_counts': {'our_method': 288, 'combined_method': 100, 'qiskit_method': 48, 'rustiq_method': 318}, 'circuit_entangling_depth': {'our_method': 132, 'combined_method': 68, 'qiskit_method': 30, 'rustiq_method': 152}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n10_e3_l1.json'}
# max_cut_benchmark_regular_n10_e3_l3.json
# {'num_paulis': 75, 'times': {'our_time': 2.824453353881836, 'combined_time': 2.529240369796753, 'qiskit_time': 0.5305836200714111, 'rustiq_time': 1.1908166408538818}, 'gate_counts': {'our_method': 702, 'combined_method': 259, 'qiskit_method': 165, 'rustiq_method': 760}, 'circuit_entangling_depth': {'our_method': 311, 'combined_method': 161, 'qiskit_method': 63, 'rustiq_method': 338}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n10_e3_l3.json'}
# max_cut_benchmark_regular_n15_e4_l1.json
# {'num_paulis': 45, 'times': {'our_time': 2.5681371688842773, 'combined_time': 2.27392578125, 'qiskit_time': 0.634303092956543, 'rustiq_time': 1.2426791191101074}, 'gate_counts': {'our_method': 645, 'combined_method': 216, 'qiskit_method': 142, 'rustiq_method': 1015}, 'circuit_entangling_depth': {'our_method': 251, 'combined_method': 107, 'qiskit_method': 58, 'rustiq_method': 422}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n15_e4_l1.json'}
# max_cut_benchmark_regular_n15_e4_l3.json
# {'num_paulis': 135, 'times': {'our_time': 7.391247987747192, 'combined_time': 7.379281282424927, 'qiskit_time': 1.2067749500274658, 'rustiq_time': 2.9182024002075195}, 'gate_counts': {'our_method': 2057, 'combined_method': 831, 'qiskit_method': 533, 'rustiq_method': 2754}, 'circuit_entangling_depth': {'our_method': 792, 'combined_method': 404, 'qiskit_method': 234, 'rustiq_method': 1127}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n15_e4_l3.json'}
# max_cut_benchmark_regular_n20_e12_l1.json
# {'num_paulis': 140, 'times': {'our_time': 20.722625732421875, 'combined_time': 20.344635486602783, 'qiskit_time': 1.518941879272461, 'rustiq_time': 2.6150131225585938}, 'gate_counts': {'our_method': 2071, 'combined_method': 872, 'qiskit_method': 793, 'rustiq_method': 2171}, 'circuit_entangling_depth': {'our_method': 793, 'combined_method': 442, 'qiskit_method': 441, 'rustiq_method': 841}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e12_l1.json'}
# max_cut_benchmark_regular_n20_e12_l3.json
# {'num_paulis': 420, 'times': {'our_time': 62.78622269630432, 'combined_time': 62.353381633758545, 'qiskit_time': 4.39725136756897, 'rustiq_time': 5.988994836807251}, 'gate_counts': {'our_method': 4944, 'combined_method': 2672, 'qiskit_method': 2571, 'rustiq_method': 5597}, 'circuit_entangling_depth': {'our_method': 2025, 'combined_method': 1256, 'qiskit_method': 1267, 'rustiq_method': 2006}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e12_l3.json'}
# max_cut_benchmark_regular_n20_e3_l1.json
# {'num_paulis': 50, 'times': {'our_time': 3.2872157096862793, 'combined_time': 3.253308057785034, 'qiskit_time': 0.44082045555114746, 'rustiq_time': 1.1539161205291748}, 'gate_counts': {'our_method': 748, 'combined_method': 247, 'qiskit_method': 125, 'rustiq_method': 777}, 'circuit_entangling_depth': {'our_method': 241, 'combined_method': 92, 'qiskit_method': 56, 'rustiq_method': 282}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e3_l1.json'}
# max_cut_benchmark_regular_n20_e3_l3.json
# {'num_paulis': 150, 'times': {'our_time': 9.672144889831543, 'combined_time': 9.957390308380127, 'qiskit_time': 1.0980665683746338, 'rustiq_time': 2.508298397064209}, 'gate_counts': {'our_method': 2258, 'combined_method': 984, 'qiskit_method': 385, 'rustiq_method': 2149}, 'circuit_entangling_depth': {'our_method': 712, 'combined_method': 461, 'qiskit_method': 109, 'rustiq_method': 722}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e3_l3.json'}
# max_cut_benchmark_regular_n20_e4_l1.json
# {'num_paulis': 60, 'times': {'our_time': 4.366334438323975, 'combined_time': 4.271584749221802, 'qiskit_time': 0.6023907661437988, 'rustiq_time': 1.5937414169311523}, 'gate_counts': {'our_method': 1098, 'combined_method': 339, 'qiskit_method': 205, 'rustiq_method': 1470}, 'circuit_entangling_depth': {'our_method': 356, 'combined_method': 165, 'qiskit_method': 72, 'rustiq_method': 467}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e4_l1.json'}
# max_cut_benchmark_regular_n20_e4_l3.json
# {'num_paulis': 180, 'times': {'our_time': 13.555776357650757, 'combined_time': 13.884898900985718, 'qiskit_time': 1.5558428764343262, 'rustiq_time': 4.202768564224243}, 'gate_counts': {'our_method': 3426, 'combined_method': 1566, 'qiskit_method': 668, 'rustiq_method': 4168}, 'circuit_entangling_depth': {'our_method': 1162, 'combined_method': 719, 'qiskit_method': 234, 'rustiq_method': 1470}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e4_l3.json'}
# max_cut_benchmark_regular_n20_e8_l1.json
# {'num_paulis': 100, 'times': {'our_time': 11.054458856582642, 'combined_time': 11.160178184509277, 'qiskit_time': 1.148930549621582, 'rustiq_time': 2.323791265487671}, 'gate_counts': {'our_method': 1826, 'combined_method': 778, 'qiskit_method': 500, 'rustiq_method': 1970}, 'circuit_entangling_depth': {'our_method': 662, 'combined_method': 394, 'qiskit_method': 282, 'rustiq_method': 694}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e8_l1.json'}
# max_cut_benchmark_regular_n20_e8_l3.json
# {'num_paulis': 300, 'times': {'our_time': 35.660706758499146, 'combined_time': 36.7497992515564, 'qiskit_time': 2.9989864826202393, 'rustiq_time': 4.358352899551392}, 'gate_counts': {'our_method': 5782, 'combined_method': 3253, 'qiskit_method': 1763, 'rustiq_method': 4144}, 'circuit_entangling_depth': {'our_method': 2278, 'combined_method': 1499, 'qiskit_method': 778, 'rustiq_method': 1419}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_max_cut_benchmark_regular_n20_e8_l3.json'}

# %%
#Labs

run_experiment_folder(folder_path = "benchmarks/labs_paulis", save_output = True, lookahead_size = 10)
# Out:
# labs_n10_layers1.json
# {'num_paulis': 80, 'times': {'our_time': 5.941126108169556, 'combined_time': 5.469384431838989, 'qiskit_time': 2.1452667713165283, 'rustiq_time': 1.538888692855835}, 'gate_counts': {'our_method': 794, 'combined_method': 352, 'qiskit_method': 738, 'rustiq_method': 788}, 'circuit_entangling_depth': {'our_method': 414, 'combined_method': 254, 'qiskit_method': 485, 'rustiq_method': 370}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n10_layers1.json'}
# labs_n10_layers3.json
# {'num_paulis': 240, 'times': {'our_time': 18.023836851119995, 'combined_time': 16.45203709602356, 'qiskit_time': 5.852362394332886, 'rustiq_time': 3.742997646331787}, 'gate_counts': {'our_method': 2381, 'combined_method': 1261, 'qiskit_method': 2437, 'rustiq_method': 2347}, 'circuit_entangling_depth': {'our_method': 1250, 'combined_method': 912, 'qiskit_method': 1655, 'rustiq_method': 1213}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n10_layers3.json'}
# labs_n11_layers1.json
# {'num_paulis': 106, 'times': {'our_time': 10.108987092971802, 'combined_time': 9.21338176727295, 'qiskit_time': 3.0707929134368896, 'rustiq_time': 2.1193361282348633}, 'gate_counts': {'our_method': 1178, 'combined_method': 490, 'qiskit_method': 1148, 'rustiq_method': 1344}, 'circuit_entangling_depth': {'our_method': 557, 'combined_method': 341, 'qiskit_method': 746, 'rustiq_method': 672}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n11_layers1.json'}
# labs_n11_layers3.json
# {'num_paulis': 318, 'times': {'our_time': 30.300033569335938, 'combined_time': 32.59589767456055, 'qiskit_time': 8.334728479385376, 'rustiq_time': 5.180157661437988}, 'gate_counts': {'our_method': 3586, 'combined_method': 1792, 'qiskit_method': 3600, 'rustiq_method': 3663}, 'circuit_entangling_depth': {'our_method': 1789, 'combined_method': 1193, 'qiskit_method': 2338, 'rustiq_method': 1806}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n11_layers3.json'}
# labs_n12_layers1.json
# {'num_paulis': 137, 'times': {'our_time': 16.182755708694458, 'combined_time': 15.69406247138977, 'qiskit_time': 3.8437294960021973, 'rustiq_time': 2.199122905731201}, 'gate_counts': {'our_method': 1650, 'combined_method': 750, 'qiskit_method': 1599, 'rustiq_method': 1521}, 'circuit_entangling_depth': {'our_method': 781, 'combined_method': 475, 'qiskit_method': 999, 'rustiq_method': 714}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n12_layers1.json'}
# labs_n12_layers3.json
# {'num_paulis': 411, 'times': {'our_time': 49.63935446739197, 'combined_time': 48.806580543518066, 'qiskit_time': 13.259568452835083, 'rustiq_time': 6.393915414810181}, 'gate_counts': {'our_method': 5134, 'combined_method': 2556, 'qiskit_method': 4919, 'rustiq_method': 4800}, 'circuit_entangling_depth': {'our_method': 2548, 'combined_method': 1624, 'qiskit_method': 3139, 'rustiq_method': 2200}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n12_layers3.json'}
# labs_n13_layers1.json
# {'num_paulis': 174, 'times': {'our_time': 26.889147520065308, 'combined_time': 26.495200395584106, 'qiskit_time': 4.773245573043823, 'rustiq_time': 3.22139310836792}, 'gate_counts': {'our_method': 2331, 'combined_method': 1021, 'qiskit_method': 2099, 'rustiq_method': 2373}, 'circuit_entangling_depth': {'our_method': 1064, 'combined_method': 613, 'qiskit_method': 1281, 'rustiq_method': 1070}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n13_layers1.json'}
# labs_n13_layers3.json
# {'num_paulis': 522, 'times': {'our_time': 82.9433581829071, 'combined_time': 80.36225914955139, 'qiskit_time': 14.772526025772095, 'rustiq_time': 9.286186456680298}, 'gate_counts': {'our_method': 7349, 'combined_method': 3568, 'qiskit_method': 6733, 'rustiq_method': 7517}, 'circuit_entangling_depth': {'our_method': 3472, 'combined_method': 2257, 'qiskit_method': 4060, 'rustiq_method': 3456}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n13_layers3.json'}
# labs_n14_layers1.json
# {'num_paulis': 217, 'times': {'our_time': 42.79664182662964, 'combined_time': 48.277992963790894, 'qiskit_time': 6.8177809715271, 'rustiq_time': 4.375308036804199}, 'gate_counts': {'our_method': 3116, 'combined_method': 1427, 'qiskit_method': 2776, 'rustiq_method': 3688}, 'circuit_entangling_depth': {'our_method': 1429, 'combined_method': 836, 'qiskit_method': 1769, 'rustiq_method': 1566}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n14_layers1.json'}
# labs_n14_layers3.json
# {'num_paulis': 651, 'times': {'our_time': 142.0923056602478, 'combined_time': 128.17050695419312, 'qiskit_time': 20.995893955230713, 'rustiq_time': 11.743619203567505}, 'gate_counts': {'our_method': 9039, 'combined_method': 4580, 'qiskit_method': 9179, 'rustiq_method': 9558}, 'circuit_entangling_depth': {'our_method': 4105, 'combined_method': 2703, 'qiskit_method': 5018, 'rustiq_method': 4366}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n14_layers3.json'}
# labs_n15_layers1.json
# {'num_paulis': 267, 'times': {'our_time': 67.17150378227234, 'combined_time': 65.3104796409607, 'qiskit_time': 8.46039342880249, 'rustiq_time': 5.345715522766113}, 'gate_counts': {'our_method': 4701, 'combined_method': 2149, 'qiskit_method': 3855, 'rustiq_method': 4761}, 'circuit_entangling_depth': {'our_method': 2081, 'combined_method': 1240, 'qiskit_method': 2311, 'rustiq_method': 1996}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n15_layers1.json'}
# labs_n15_layers3.json
# {'num_paulis': 801, 'times': {'our_time': 200.26685214042664, 'combined_time': 201.35993361473083, 'qiskit_time': 26.204975605010986, 'rustiq_time': 16.168792486190796}, 'gate_counts': {'our_method': 13561, 'combined_method': 6587, 'qiskit_method': 12325, 'rustiq_method': 13860}, 'circuit_entangling_depth': {'our_method': 6170, 'combined_method': 3693, 'qiskit_method': 6374, 'rustiq_method': 6283}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n15_layers3.json'}
# labs_n16_layers1.json
# {'num_paulis': 324, 'times': {'our_time': 101.72518515586853, 'combined_time': 100.74878120422363, 'qiskit_time': 10.49595308303833, 'rustiq_time': 6.729018449783325}, 'gate_counts': {'our_method': 4820, 'combined_method': 2765, 'qiskit_method': 4856, 'rustiq_method': 5604}, 'circuit_entangling_depth': {'our_method': 2115, 'combined_method': 1541, 'qiskit_method': 2689, 'rustiq_method': 2486}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n16_layers1.json'}
# labs_n16_layers3.json
# {'num_paulis': 972, 'times': {'our_time': 307.0584888458252, 'combined_time': 305.2104275226593, 'qiskit_time': 32.64376926422119, 'rustiq_time': 19.48293709754944}, 'gate_counts': {'our_method': 16738, 'combined_method': 8664, 'qiskit_method': 15283, 'rustiq_method': 15693}, 'circuit_entangling_depth': {'our_method': 7638, 'combined_method': 4997, 'qiskit_method': 8176, 'rustiq_method': 7206}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n16_layers3.json'}
# labs_n17_layers1.json
# {'num_paulis': 389, 'times': {'our_time': 151.83028388023376, 'combined_time': 148.91706943511963, 'qiskit_time': 12.762894630432129, 'rustiq_time': 7.6316070556640625}, 'gate_counts': {'our_method': 5640, 'combined_method': 3450, 'qiskit_method': 5894, 'rustiq_method': 6282}, 'circuit_entangling_depth': {'our_method': 2524, 'combined_method': 1869, 'qiskit_method': 3274, 'rustiq_method': 2716}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n17_layers1.json'}
# labs_n17_layers3.json
# {'num_paulis': 1167, 'times': {'our_time': 463.27704668045044, 'combined_time': 456.95493960380554, 'qiskit_time': 38.35451149940491, 'rustiq_time': 24.46961236000061}, 'gate_counts': {'our_method': 17152, 'combined_method': 11304, 'qiskit_method': 18115, 'rustiq_method': 18905}, 'circuit_entangling_depth': {'our_method': 7738, 'combined_method': 5963, 'qiskit_method': 9888, 'rustiq_method': 8470}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n17_layers3.json'}
# labs_n18_layers1.json
# {'num_paulis': 462, 'times': {'our_time': 222.50941681861877, 'combined_time': 220.55563712120056, 'qiskit_time': 14.835357904434204, 'rustiq_time': 9.316106796264648}, 'gate_counts': {'our_method': 6897, 'combined_method': 4218, 'qiskit_method': 6838, 'rustiq_method': 9239}, 'circuit_entangling_depth': {'our_method': 3056, 'combined_method': 2223, 'qiskit_method': 3918, 'rustiq_method': 3769}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n18_layers1.json'}
# labs_n18_layers3.json
# {'num_paulis': 1386, 'times': {'our_time': 685.5381283760071, 'combined_time': 671.7689197063446, 'qiskit_time': 45.50839352607727, 'rustiq_time': 31.23952317237854}, 'gate_counts': {'our_method': 22187, 'combined_method': 14256, 'qiskit_method': 21364, 'rustiq_method': 27318}, 'circuit_entangling_depth': {'our_method': 9858, 'combined_method': 7293, 'qiskit_method': 11608, 'rustiq_method': 11612}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n18_layers3.json'}
# labs_n19_layers1.json
# {'num_paulis': 544, 'times': {'our_time': 328.5161509513855, 'combined_time': 321.50189208984375, 'qiskit_time': 27.90543270111084, 'rustiq_time': 11.248940229415894}, 'gate_counts': {'our_method': 9312, 'combined_method': 5916, 'qiskit_method': 8429, 'rustiq_method': 10298}, 'circuit_entangling_depth': {'our_method': 3928, 'combined_method': 3055, 'qiskit_method': 4696, 'rustiq_method': 4298}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n19_layers1.json'}
# labs_n19_layers3.json
# {'num_paulis': 1632, 'times': {'our_time': 987.579021692276, 'combined_time': 986.9666593074799, 'qiskit_time': 57.23804950714111, 'rustiq_time': 38.027385234832764}, 'gate_counts': {'our_method': 27260, 'combined_method': 18253, 'qiskit_method': 26036, 'rustiq_method': 28677}, 'circuit_entangling_depth': {'our_method': 11972, 'combined_method': 9278, 'qiskit_method': 14285, 'rustiq_method': 12418}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n19_layers3.json'}
# labs_n20_layers1.json
# {'num_paulis': 635, 'times': {'our_time': 433.33792448043823, 'combined_time': 409.8468208312988, 'qiskit_time': 20.42841124534607, 'rustiq_time': 11.689762830734253}, 'gate_counts': {'our_method': 10584, 'combined_method': 6678, 'qiskit_method': 10013, 'rustiq_method': 10359}, 'circuit_entangling_depth': {'our_method': 4491, 'combined_method': 3467, 'qiskit_method': 5509, 'rustiq_method': 4350}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n20_layers1.json'}
# labs_n20_layers3.json
# {'num_paulis': 1905, 'times': {'our_time': 1241.7717773914337, 'combined_time': 1241.9812185764313, 'qiskit_time': 59.17786526679993, 'rustiq_time': 41.38640880584717}, 'gate_counts': {'our_method': 35763, 'combined_method': 23575, 'qiskit_method': 31302, 'rustiq_method': 33906}, 'circuit_entangling_depth': {'our_method': 15665, 'combined_method': 11851, 'qiskit_method': 16469, 'rustiq_method': 14666}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n20_layers3.json'}
# labs_n5_layers1.json
# {'num_paulis': 12, 'times': {'our_time': 0.7041168212890625, 'combined_time': 0.37400150299072266, 'qiskit_time': 0.29421377182006836, 'rustiq_time': 0.2513282299041748}, 'gate_counts': {'our_method': 47, 'combined_method': 27, 'qiskit_method': 35, 'rustiq_method': 42}, 'circuit_entangling_depth': {'our_method': 36, 'combined_method': 25, 'qiskit_method': 32, 'rustiq_method': 29}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n5_layers1.json'}
# labs_n5_layers3.json
# {'num_paulis': 36, 'times': {'our_time': 1.469074010848999, 'combined_time': 0.7669508457183838, 'qiskit_time': 0.6392917633056641, 'rustiq_time': 0.4218730926513672}, 'gate_counts': {'our_method': 141, 'combined_method': 68, 'qiskit_method': 128, 'rustiq_method': 94}, 'circuit_entangling_depth': {'our_method': 107, 'combined_method': 63, 'qiskit_method': 110, 'rustiq_method': 73}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n5_layers3.json'}
# labs_n6_layers1.json
# {'num_paulis': 19, 'times': {'our_time': 0.8377606868743896, 'combined_time': 0.5375645160675049, 'qiskit_time': 0.5694782733917236, 'rustiq_time': 0.3650238513946533}, 'gate_counts': {'our_method': 93, 'combined_method': 43, 'qiskit_method': 78, 'rustiq_method': 95}, 'circuit_entangling_depth': {'our_method': 62, 'combined_method': 41, 'qiskit_method': 63, 'rustiq_method': 69}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n6_layers1.json'}
# labs_n6_layers3.json
# {'num_paulis': 57, 'times': {'our_time': 1.8081679344177246, 'combined_time': 1.4600999355316162, 'qiskit_time': 0.8038506507873535, 'rustiq_time': 0.8078410625457764}, 'gate_counts': {'our_method': 274, 'combined_method': 161, 'qiskit_method': 270, 'rustiq_method': 180}, 'circuit_entangling_depth': {'our_method': 181, 'combined_method': 135, 'qiskit_method': 223, 'rustiq_method': 126}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n6_layers3.json'}
# labs_n7_layers1.json
# {'num_paulis': 29, 'times': {'our_time': 1.0631599426269531, 'combined_time': 1.04520583152771, 'qiskit_time': 0.5565128326416016, 'rustiq_time': 0.7111003398895264}, 'gate_counts': {'our_method': 208, 'combined_method': 91, 'qiskit_method': 157, 'rustiq_method': 198}, 'circuit_entangling_depth': {'our_method': 124, 'combined_method': 74, 'qiskit_method': 113, 'rustiq_method': 123}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n7_layers1.json'}
# labs_n7_layers3.json
# {'num_paulis': 87, 'times': {'our_time': 3.046858310699463, 'combined_time': 2.401583194732666, 'qiskit_time': 1.3194737434387207, 'rustiq_time': 1.2995274066925049}, 'gate_counts': {'our_method': 508, 'combined_method': 240, 'qiskit_method': 509, 'rustiq_method': 549}, 'circuit_entangling_depth': {'our_method': 309, 'combined_method': 211, 'qiskit_method': 383, 'rustiq_method': 347}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n7_layers3.json'}
# labs_n8_layers1.json
# {'num_paulis': 42, 'times': {'our_time': 1.7702693939208984, 'combined_time': 1.6515867710113525, 'qiskit_time': 1.1140239238739014, 'rustiq_time': 0.8437440395355225}, 'gate_counts': {'our_method': 297, 'combined_method': 162, 'qiskit_method': 313, 'rustiq_method': 363}, 'circuit_entangling_depth': {'our_method': 167, 'combined_method': 124, 'qiskit_method': 252, 'rustiq_method': 202}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n8_layers1.json'}
# labs_n8_layers3.json
# {'num_paulis': 126, 'times': {'our_time': 5.384613037109375, 'combined_time': 4.4840168952941895, 'qiskit_time': 2.2240564823150635, 'rustiq_time': 1.800189733505249}, 'gate_counts': {'our_method': 954, 'combined_method': 481, 'qiskit_method': 933, 'rustiq_method': 886}, 'circuit_entangling_depth': {'our_method': 559, 'combined_method': 366, 'qiskit_method': 686, 'rustiq_method': 538}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n8_layers3.json'}
# labs_n9_layers1.json
# {'num_paulis': 59, 'times': {'our_time': 3.2782416343688965, 'combined_time': 2.8045051097869873, 'qiskit_time': 1.0442087650299072, 'rustiq_time': 1.042215347290039}, 'gate_counts': {'our_method': 553, 'combined_method': 225, 'qiskit_method': 508, 'rustiq_method': 649}, 'circuit_entangling_depth': {'our_method': 290, 'combined_method': 165, 'qiskit_method': 344, 'rustiq_method': 321}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n9_layers1.json'}
# labs_n9_layers3.json
# {'num_paulis': 177, 'times': {'our_time': 9.329071521759033, 'combined_time': 8.21903657913208, 'qiskit_time': 3.644261121749878, 'rustiq_time': 2.3856260776519775}, 'gate_counts': {'our_method': 1591, 'combined_method': 727, 'qiskit_method': 1585, 'rustiq_method': 1463}, 'circuit_entangling_depth': {'our_method': 849, 'combined_method': 543, 'qiskit_method': 1125, 'rustiq_method': 773}, 'test_paulis_file': 'benchmarks/results_hardware_topology_ibm_sherbrooke/test_labs_n9_layers3.json'}

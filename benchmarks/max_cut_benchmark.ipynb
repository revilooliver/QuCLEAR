# %%
import importlib
import max_cut_benchmark as maxcut
importlib.reload(maxcut)

nodes=5
num_edges=nodes*(nodes-1)
totter_number=10 #number of qaoa layers
graph=maxcut.build_graph(nodes, num_edges)
paulis=maxcut.max_cut_pauli_layers(graph, totter_number)
print(paulis)
maxcut.save_to_json(paulis, f"max_cut_benchmark_n{nodes}_e{num_edges}.json")
# Out:
# [['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX'], ['IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'], ['XIIII', 'IXIII', 'IIXII', 'IIIXI', 'IIIIX']]

# %%
import importlib
import max_cut_benchmark as maxcut
importlib.reload(maxcut)

nodes=10
num_edges=nodes*(nodes-1)// 2
totter_number=5 #number of qaoa layers
graph=maxcut.build_graph(nodes, num_edges)
paulis=maxcut.max_cut_pauli_layers(graph, totter_number)
flattened_paulis = [item for sublist in paulis for item in sublist]
len(flattened_paulis)
maxcut.save_to_json(flattened_paulis, f"max_cut_benchmark_n{nodes}_e{num_edges}_l{totter_number}.json")
